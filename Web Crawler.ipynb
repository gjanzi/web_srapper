# %% [markdown]
# # Python Web Crawler for BBQ restaurants in Austin (TX)

# %% [markdown]
# Importing relevant packages:

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## Retrieving the restaurant names and links

# %%
# Get the URL without the last number (so it says start= at the end)
url = 'https://www.yelp.com/search?cflt=bbq&find_loc=Austin%2C%20TX&start='

# Create two empty lists
name_restaurant = []
link_restaurant = []

# For each page, collect the restaurant names and links
for j in range(0,23):
    
    html = requests.get(url + str(j*10))
    
    soup = BeautifulSoup(html.content, 'lxml')
    links = soup.select(".css-1pxmz4g .css-166la90")
   
    for link in links:
        name_restaurant.append(link.string)
        link_restaurant.append(link.get('href'))

# %%
# Check the names
name_restaurant
# Out:
# ['Terry Black’s Barbecue',
#  'Franklin Barbecue',
#  'la Barbecue',
#  'The Salt Lick BBQ',
#  'The Original Black’s Barbecue',
#  'Cooper’s Old Time Pit Bar-B-Que',
#  'Lamberts Downtown Barbecue',
#  'SLAB BBQ & Beer',
#  'Micklethwait Craft Meats',
#  'Stiles Switch BBQ & Brew',
#  'Fowler’s Smokin Soul Food',
#  'Rollin Smoke BBQ',
#  'Bigg Belly BBQ',
#  'Rudy’s “Country Store” and Bar-B-Q',
#  'King’s BBQ and Soul',
#  'County Line On The Lake',
#  'Big Vinny’s Bbq',
#  'Brown’s Bar-B-Que',
#  'Iron Works Barbecue',
#  'Stubb’s Bar-B-Q',
#  'Jim’s Smokehouse',
#  'Scotty’s BBQ',
#  'Rudy’s “Country Store” and Bar-B-Q',
#  'CM Smokehouse',
#  'Valentina’s Tex Mex BBQ',
#  'Metcalf Barbecue',
#  'The Mean Eyed Cat',
#  'House Park Bar-B-Q',
#  'Interstellar BBQ',
#  'Mum Foods',
#  'Kerlin BBQ',
#  'Louie Mueller Barbecue',
#  'Moreno Barbecue',
#  'The Salt Lick BBQ',
#  'Rudy’s “Country Store” and Bar-B-Q',
#  'Metcalf Barbecue',
#  'The Salt Lick BBQ - Austin Airport',
#  'The Mean Eyed Cat',
#  'Bar-B-Q Heaven',
#  'Texas Ranch BBQ',
#  'The County Line',
#  'Up N Smoke BBQ',
#  'Big O’s Pit BBQ',
#  'Lula Mae’s Catering and BBQ',
#  'Southside Market & Barbeque',
#  'Fitties',
#  'Southside Market & Barbeque - Austin at Arbor Walk',
#  'The Salt Lick BBQ - Austin Airport',
#  'It’s All Good BBQ',
#  'B Cooper Barbecue',
#  'Opie’s BBQ',
#  'Leroy and Lewis Barbecue',
#  'The Salt Lick BBQ',
#  'Stiles Switch BBQ & Brew',
#  'Sniffies Bar B-Que',
#  'Pok-e-Jo’s Smokehouse',
#  'Double FF BBQ',
#  'Pok-e-Jo’s Smokehouse',
#  'Henry’s barbecue',
#  'Donn’s BBQ',
#  'Island Fork',
#  'Big O’s Pit BBQ',
#  'Pok-e-Jo’s Smokehouse',
#  'Lula Mae’s Catering and BBQ',
#  'Bohemian Barbecue',
#  'Benny’s Texas BBQ',
#  'Donn’s BBQ',
#  'Davis Grocery and Bar-B-Q',
#  'Meyer’s Elgin Smokehouse',
#  'Pok-e-Jo’s Smokehouse',
#  'Dirty Glove Midwest BBQ',
#  'Taco Bronco Pop Up',
#  'JNL Barbecue',
#  'Bohemian Barbecue',
#  'Benny’s Texas BBQ',
#  'HOTSWORDS',
#  'Creekside Cookers BBQ',
#  'Meyer’s Elgin Smokehouse',
#  'Ladybird’s Austin Kitchen',
#  'Gebby’s BBQ & Catering',
#  'Gebby’s BBQ & Catering',
#  'Green Mesquite BBQ & More',
#  'Liberty Barbecue',
#  'Lucky’s BBQ',
#  'Keith’s BBQ',
#  'Chi’Lantro',
#  'Tllt Bbq',
#  'Chi’Lantro',
#  'Jjim Korean Braised BBQ',
#  'Svrcek’s Best BBQ',
#  'Stubbs At Graceland Grocery',
#  'Chi’Lantro',
#  'Alzer’s BBQ',
#  'Buckalew’s BBQ',
#  'Crimson Creek Smokehouse',
#  'Hello Sweetie BBQ & More',
#  'Sam’s Bar-B-Que',
#  'Best Dam BBQ Joint',
#  'It’s Too Good 2 Be True',
#  'Oakwood BBQ',
#  'Green Mesquite BBQ & More',
#  'True Texas BBQ',
#  'The Switch',
#  'Louie’s Craft BBQ',
#  'Willie’s Joint Bar and Grill',
#  'Gibson’s Cantina',
#  'Chi’Lantro',
#  'Southside Market & Barbeque - Hutto',
#  'Pustka Family Barbeque',
#  'Danny’s BBQ',
#  'Cele Store',
#  'Bee Caves BBQ',
#  'Sundance BBQ',
#  'Donn’s BBQ & Catering',
#  'Sam’s Bar-B-Que',
#  'Jamie’s barbecue and mini tacos',
#  'The Water Trough at Lone Star Court',
#  'Willie’s Bar-B-Que',
#  'Pok-E-Jo’s Smokehouse',
#  'Hula Pig Hawaiian BBQ',
#  'Crimson Creek Smokehouse',
#  'Kyote Junction',
#  'The Wicked Pit',
#  'Chi’Lantro',
#  'BBQ at Frankie’s',
#  'Bert’s Bar-B-Q',
#  'Big Os BBQ, Burgers And More',
#  'Simpson’s BBQ',
#  'Jan Chi Korean Cuisine & BBQ',
#  'Baker’s Brisket',
#  'Hula Pig Hawaiian BBQ',
#  'Rudy’s “Country Store” and Bar-B-Q',
#  'Gyu-Kaku Japanese BBQ',
#  'Kyote Junction',
#  'Louie’s Craft BBQ',
#  'Freddie’s Smokehouse BBQ',
#  'Cele Store',
#  'Whoa BBQ - Native Hostel',
#  'Chi’Lantro BBQ',
#  'Pustka Family Barbeque',
#  'Bill Miller Bar-B-Q',
#  'Smokey Mo’s BBQ - Avery Ranch',
#  'Jjim Korean Braised BBQ',
#  'J&J BBQ & Burgers',
#  'Bill Miller Bar-B-Q',
#  'It’s Too Good 2 Be True',
#  'True Texas BBQ',
#  'Texas Roadhouse',
#  'Little Mac’s Smokehouse',
#  'Ted’s Farm Bbq',
#  'Smokey J’s Barbeque',
#  'Big Os BBQ, Burgers And More',
#  'The Wicked Pit',
#  'Danny’s BBQ',
#  'Taquizas Mariana',
#  'Southside Market & Barbeque - Hutto',
#  'Chi’Lantro',
#  'Hoof & Horn BBQ',
#  'Little Mac’s Smokehouse',
#  'Billy Ray’s Barbeque King',
#  'Pok-E-Jo’s Smokehouse',
#  'Chi’Lantro',
#  'Shugabees BBQ',
#  'Wunder Pig Barbecue',
#  'Down South Texas BBQ',
#  'Charm Korean BBQ',
#  'Cantwell’s Old Scholl Bbq',
#  'Bill Miller Bar-B-Q',
#  'Pat’s BBQ',
#  'Dad’s Place',
#  'Paw Paw’s BBQ',
#  'J&J BBQ & Burgers',
#  'Smokey Mo’s BBQ - Avery Ranch',
#  'Willie’s Catering BBQ and Burgers',
#  'Alexander’s BBQ',
#  'Pok-E-Jo’s Smokehouse',
#  'Chosun Korean BBQ',
#  'Bill Miller Bar-B-Q',
#  'Fairchild Barbecue',
#  'Simpson’s BBQ',
#  'Rudy’s “Country Store” and Bar-B-Q',
#  'Chew Chew BBQ - Temp. CLOSED',
#  'J&J BBQ and Burgers',
#  'Mayham’s Juicy Katering',
#  'Bill Miller Bar-B-Q',
#  'Metcalf Barbecue',
#  'RICHARD’S BACK PORCH BBQ',
#  'Rogers Boyz Family BBQ Company',
#  'Chi’Lantro',
#  'HEB',
#  'Catering By Mopsie',
#  'Hoof & Horn BBQ',
#  'Austin BBQ',
#  'Smokey Mo’s BBQ - Round Rock',
#  'Fairchild Barbecue',
#  'Bill Miller Bar-B-Q',
#  'Chosun Korean BBQ',
#  'Bill Miller Bar-B-Q',
#  'Reflectionz BBQ and More',
#  'HBQ',
#  'Shugabees BBQ',
#  'Bill Miller Bar-B-Q',
#  'MWS Catering LLC',
#  'Austin Wing Company',
#  'The Naughty Texan',
#  'HBQ',
#  'Sogongdong Tofu & BBQ',
#  'Amigo’s BBQ Grill',
#  'Famous Dave’s Bar-B-Que',
#  'Richard Jones Bar-B-Que & Restaurants & Catering',
#  'The Rusty Cleaver',
#  'Korea House',
#  'Bill Miller Bar-B-Q',
#  'Sogongdong Tofu & BBQ',
#  'Richard Jones Bar-B-Que & Restaurants & Catering',
#  'The Naughty Texan',
#  'Chef Z Austin',
#  'Dripping Wings',
#  'Tasty Cuisine Catering',
#  'Morelia Mexican Grill',
#  'Ho Ho Chinese BBQ',
#  'Dripping Wings',
#  'Gebby’s BBQ & Catering',
#  'Smokey Mo’s BBQ - Round Rock',
#  'Smokey Mo’s BBQ - Liberty Hill',
#  'Smokey Mo’s BBQ - Cedar Park',
#  'Chi’Lantro',
#  'OH-HO Chinese BBQ and Asian Cuisine',
#  'Morelia Mexican Grill',
#  'Novas’']

# %% [markdown]
# ### Adding the beginning for all links (http://www.yelp.com)

# %%
# Complete the restaurant links
link_restaurant=["https://www.yelp.com" + s for s in link_restaurant]
print(link_restaurant[0:5])
# Out:
# ['https://www.yelp.com/biz/terry-blacks-barbecue-austin', 'https://www.yelp.com/biz/franklin-barbecue-austin', 'https://www.yelp.com/biz/la-barbecue-austin-3', 'https://www.yelp.com/biz/the-salt-lick-bbq-driftwood', 'https://www.yelp.com/biz/the-original-black-s-barbecue-austin']

# %% [markdown]
# ### Creating a dataframe with all restaurant names and links

# %%
# Create a Zipped list of the restaurant names and links
RestaurantDataSet = list(zip(name_restaurant,link_restaurant))

# Create a dataframe of two columns
df_restaurants = pd.DataFrame(data = RestaurantDataSet , columns=['name', 'url'])

# %%
# View dataframe
df_restaurants.iloc[:15]
# Out:
#                                   name  \
# 0               Terry Black’s Barbecue
# 1                    Franklin Barbecue
# 2                          la Barbecue
# 3                    The Salt Lick BBQ
# 4        The Original Black’s Barbecue
# 5      Cooper’s Old Time Pit Bar-B-Que
# 6           Lamberts Downtown Barbecue
# 7                      SLAB BBQ & Beer
# 8             Micklethwait Craft Meats
# 9             Stiles Switch BBQ & Brew
# 10           Fowler’s Smokin Soul Food
# 11                    Rollin Smoke BBQ
# 12                      Bigg Belly BBQ
# 13  Rudy’s “Country Store” and Bar-B-Q
# 14                 King’s BBQ and Soul
#
#                                                   url
# 0   https://www.yelp.com/biz/terry-blacks-barbecue...
# 1   https://www.yelp.com/biz/franklin-barbecue-austin
# 2       https://www.yelp.com/biz/la-barbecue-austin-3
# 3   https://www.yelp.com/biz/the-salt-lick-bbq-dri...
# 4   https://www.yelp.com/biz/the-original-black-s-...
# 5   https://www.yelp.com/biz/coopers-old-time-pit-...
# 6   https://www.yelp.com/biz/lamberts-downtown-bar...
# 7   https://www.yelp.com/biz/slab-bbq-and-beer-austin
# 8   https://www.yelp.com/biz/micklethwait-craft-me...
# 9   https://www.yelp.com/biz/stiles-switch-bbq-and...
# 10  https://www.yelp.com/biz/fowlers-smokin-soul-f...
# 11   https://www.yelp.com/biz/rollin-smoke-bbq-austin
# 12     https://www.yelp.com/biz/bigg-belly-bbq-austin
# 13  https://www.yelp.com/biz/rudys-country-store-a...
# 14  https://www.yelp.com/biz/kings-bbq-and-soul-au...

# %%
# Write a CSV of all the restaurants and their links
df_restaurants.to_csv('Austin_BBQ_Restaurants.csv',
                      index=False,header=True,encoding='utf8')

# %% [markdown]
# ## Going through the subpages

# %%
url_sub = df_restaurants['url'][0]
name_business = df_restaurants['name'][0]
print(name_business, url_sub)
# Out:
# Terry Black’s Barbecue https://www.yelp.com/biz/terry-blacks-barbecue-austin

# %%
html_sub = requests.get(url_sub)
soup_sub = BeautifulSoup(html_sub.content, 'lxml')
soup_sub
# Out:
# <!DOCTYPE HTML>
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]--><!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]--><!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]--><!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script nonce="7366194a">
#             (function() {
#                 var main = null;
#
#                 var main=function(){window.onerror=function(k,a,c,i,f){var j=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true"||navigator.userAgent==="selenium");var h=f&&(f.name==="ServerSideRenderingError"||f.name==="CSRFallbackError");if(j&&!h){document.body.innerHTML="<h1>Javascript Error Detected</h1>";var g=document.createElement("div");g.setAttribute("id","pastebinTraceback");var d=document.createElement("code");var e={message:k,source:a,lineno:c,colno:i,error:f};var b=document.createTextNode("JS ERROR DETECTED\n"+window.JSON.stringify(e,null,2));
# d.appendChild(b);g.appendChild(d);document.getElementsByTagName("body")[0].appendChild(g)}}};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <link href="https://s3-media0.fl.yelpcdn.com" rel="dns-prefetch"/>
# <link href="https://www.google.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://www.facebook.com" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net" rel="dns-prefetch"/>
# <link href="https://maps.googleapis.com" rel="dns-prefetch"/>
# <link href="https://js.adsrvr.org" rel="dns-prefetch"/>
# <link href="https://stats.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://idsync.rlcdn.com" rel="dns-prefetch"/>
# <script>            window.yPageStart = new Date().getTime();
# </script>
# <script>            var initialVisibilityState = document.webkitVisibilityState;
#
#                 yPerfTimings = [];
#
#                 ySitRepParams = {"uniqueRequestID": "7366194a9732fea9", "zipkinTraceID": "6ae94d4d39a34842", "cfRayID": null, "yuv_record": "bQo0WIhalfRc6oQEFOmWjkLEU-JOYBesvEMWW9fiP4fGxBaOt2QrnHuHiFaEdjwFp3OREYEkB1kDr_S5I-4NV7jTyAqEAv0f", "serverStartTime": 1622285500597, "datacenter": "us-east-1", "site": "main", "isLoggedIn": false, "action": null, "servlet": "biz_details", "clientIP": "178.239.173.196", "is_internal_ip": false, "edgeStartTime": 1622285500548741, "b3Sampled": "0", "edgestageSubdomain": "_disabled", "disableBeacon": false};
#                 window.ySitRepParams['initialVisibilityState'] = initialVisibilityState;
#                 window.ySitRepParams['seoCohorts'] = [["amp_biz_details", "status_quo"], ["biz_conditional_raq_title_experiment", "raq_ruleset2_01"], ["biz_growth.biz_site_verify_with_work_email_v2", "enabled"], ["biz_growth.category_specific_claim_callouts", "status_quo"], ["biz_site_new_business_user_onboarding", "status_quo"], ["biz_site_self_serve_cpc_re_v2", "00_status_quo"], ["biz_site_yes_it_works_rollout", "status_quo"], ["contributions.biz_owner_respond_to_new_review_email", "enabled"], ["traffic_biz_details_title_v6_transactions_v3", "conditions_1"], ["traffic_category_city_category_browse_experiment", "category_city_0"], ["traffic_critical_css_on_msite", "conservative_1"], ["traffic_desc_search_title_last_updated_experiment", "with_last_updated_1"], ["traffic_index_new_pages_cross_validation", "test_group"], ["traffic_internal_linking_biz_details_to_raq_searches", "enabled"], ["traffic_main_biz_experiment_toggle", "enabled"], ["traffic_nearme_optimization_experiment", "treatment"], ["traffic_nearme_redesign_experiment", "redesign_0"], ["traffic_nearme_smart_banner_experiment", "smart_banner"], ["traffic_pagination_seo_experiment", "indexed_pagination_1"], ["traffic_remove_canonical_links_on_paginated_pages", "no_canonical_1"], ["traffic_remove_cdn_sharding_exp", "remove_cdn_sharding_0"], ["traffic_search_internal_linking_experiment_v2", "linked_1"], ["traffic_search_internal_linking_home_cleaning", "linked_0"], ["traffic_search_internal_linking_service_offerings", "linked_1"], ["traffic_search_internal_linking_top_searches", "linked_1"], ["traffic_search_url_normalization", "enabled"], ["traffic_search_url_normalization_experiment_v3", "status_quo_01"], ["traffic_top_searches_for_sitemap", "linked_0"], ["traffic_top_searches_through_cordite", "disabled"], ["www_biz_owner_identification", "v4"], ["www_boi_holdout_experiment_2020_q1", "prompts_enabled"], ["www_boi_modal_callouts_v2", "claim_biz_for_free"], ["yelp.www.search.traffic_bunsen_calibration_experiment", "NA_cohort_allocation_comes_from_bunsen"]];
#
#
#             (function(H){H.className=H.className.replace(/\bno-js\b/,'js');})(document.documentElement);
# </script>
# <script>            pageSpeedCustomTimestamps = {};
# </script>
# <script>            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 !function(t){function e(n){if(i[n])return i[n].exports;var r=i[n]={i:n,l:!1,exports:{}};return t[n].call(r.exports,r,r.exports,e),r.l=!0,r.exports}var i={};e.m=t,e.c=i,e.d=function(t,i,n){e.o(t,i)||Object.defineProperty(t,i,{configurable:!1,enumerable:!0,get:n})},e.n=function(t){var i=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(i,"a",i),i},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=9)}([function(t,e,i){"use strict";i.d(e,"c",function(){return r}),i.d(e,"b",function(){return s}),i.d(e,"a",function(){return o});var n=i(5),r="global",s="biz",o="biz_gtag",a=[r,"m","www",s,"webview","api","admin","error_pages",o],c=function(t,e){if(Object(n.a)(a,e)>=0)return[e,t].join(".");throw new Error("google analytics attempted to set "+t+" to an unrecognized tracker alias: "+e)};e.d=c},function(t,e,i){"use strict";function n(t){for(var e=1;e<arguments.length;e++){var i=null!=arguments[e]?arguments[e]:{},n=Object.keys(i);"function"==typeof Object.getOwnPropertySymbols&&(n=n.concat(Object.getOwnPropertySymbols(i).filter(function(t){return Object.getOwnPropertyDescriptor(i,t).enumerable}))),n.forEach(function(e){r(t,e,i[e])})}return t}function r(t,e,i){return e in t?Object.defineProperty(t,e,{value:i,enumerable:!0,configurable:!0,writable:!0}):t[e]=i,t}var s=i(2),o=i.n(s),a=i(3),c=i(4),u=i(0),f=i(6);Object.keys||o.a.shim(),Object.entries||(Object.entries=function(t){for(var e=Object.keys(t),i=new Array(e.length),n=0;n<e.length;n+=1)i[n]=[e[n],t[e[n]]];return i});var l=function(){function t(t){r(this,"clientID",void 0),r(this,"dimensions",void 0),r(this,"domain",void 0),r(this,"friendlyMap",void 0),r(this,"jsDimensions",void 0),r(this,"metrics",void 0),r(this,"temporaryDimensions",void 0),r(this,"temporaryMetrics",void 0),r(this,"trackers",void 0),r(this,"userID",void 0),r(this,"enableHighVolumeEvents",void 0),window.ga||(window.ga=function(){}),window.gtag||(window.gtag=function(){}),this.reload(t)}var e=t.prototype;return e.setupTrackers=function(){var t=this;this.friendlyMap={},this.temporaryDimensions={},this.temporaryMetrics={},Object.entries(this.trackers).forEach(function(e){var i=e[0],n=e[1];t.setupTracker(String(i),String(n))})},e.setupTracker=function(t,e){var i=this,r=n({cookieDomain:this.domain,name:t,clientId:this.clientID},this.userID?{userId:this.userID}:{});window.ga("create",e,r),this.friendlyMap[t]={},this.temporaryDimensions[t]={},this.temporaryMetrics[t]={},this.addDimensionsToFriendlyMap(t,this.dimensions),this.addDimensionsToFriendlyMap(t,this.jsDimensions),this.dimensions[t]&&Object.keys(this.dimensions[t]).forEach(function(e){i.setDimension(String(e),i.dimensions[t][e][1])}),this.metrics[t]&&Object.keys(this.metrics[t]).forEach(function(e){i.setMetric(i.metrics[t][e][0],i.metrics[t][e][1],t)}),window.ga(Object(u.d)("set",t),"anonymizeIp",!0)},e.addDimensionsToFriendlyMap=function(t,e){var i=this;e&&e[t]&&Object.keys(e[t]).forEach(function(n){i.friendlyMap[t][n]=e[t][n][0]})},e.firePageviews=function(t){var e=this;Object.keys(this.trackers).forEach(function(i){e.firePageview(String(i),t)})},e.firePageviewsWithGlobalTrackerSampled=function(t){var e=this;Object.keys(this.trackers).forEach(function(i){(i!==u.c||e.enableHighVolumeEvents)&&e.firePageview(String(i),t)})},e.firePageview=function(t,e){if(t===u.a){var i=this.trackers[t],r=n({},this.dimensions[t],this.jsDimensions[t]),s=Object.keys(r).map(function(t){return r[t]}).reduce(function(t,e){var i,r=e[0],s=e[1];return n({},t,(i={},i["dimension"+r]=null===s?s:s.toString(),i))},{}),o=this.metrics[t]||{},a=Object.keys(o).map(function(t){return o[t]}).reduce(function(t,e){var i,r=e[0],s=e[1];return n({},t,(i={},i["metric"+r]=s,i))},{});window.gtag("event","page_view",n({send_to:i,anonymize_ip:!0,cookie_domain:this.domain,client_id:this.clientID},s,a,this.userID?{user_id:this.userID}:{},e?{page_path:e}:{}))}else e&&window.ga(Object(u.d)("set",t),"page",e),window.ga(Object(u.d)("send",t),"pagev ...
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main({"clientID": "D87908105FB7A418", "dimensions": {"global": {"account_level": [1, "anon"], "biz_closed": [4, "False"], "biz_review_count": [6, "100+"], "category_paths_to_root": [10, "[['bbq', 'restaurants'], ['sandwiches', 'restaurants'], ['southern', 'restaurants']]"], "content_country": [11, "US"], "distil": [12, null], "distil_js_enabled": [13, null], "full_url": [15, "/biz/terry-blacks-barbecue-austin"], "has_canonical": [16, "False"], "integration": [17, ""], "internal_ip": [18, "False"], "is_indexable": [19, "True"], "known_bot": [36, "other"], "rating": [27, 4.5], "referrer": [28, "none"], "top_level_categories": [7, "restaurants"]}, "www": {"account_level": [1, "anon"], "biz_city_state": [192, "Austin, TX"], "biz_closed": [8, "False"], "biz_review_count": [10, "100+"], "business_id": [141, "YZs1gNSh_sN8JmN_nrpxeA"], "category_paths_to_root": [94, "[['bbq', 'restaurants'], ['sandwiches', 'restaurants'], ['southern', 'restaurants']]"], "content_country": [15, "US"], "decrypted_yuv_id": [3, "D87908105FB7A418"], "distil": [53, null], "distil_js_enabled": [138, null], "full_url": [34, "/biz/terry-blacks-barbecue-austin"], "has_canonical": [36, "False"], "integration": [14, ""], "internal_ip": [27, "False"], "is_biz_user": [129, "False"], "is_indexable": [42, "True"], "known_bot": [186, "other"], "rating": [114, 4.5], "referrer": [64, "none"], "remote_ip": [4, "178.239.173.0"], "second_level_categories": [110, "bbq, sandwiches, southern"], "service": [107, "yelp-main"], "top_level_categories": [11, "restaurants"], "viewport_tracking": [29, null], "ad.web_carousel_bottom_of_biz": [78, "status_quo"], "www_education_banner": [190, "disabled"], "contributions.www.remove_review_draft_modules": [183, "status_quo"], "contributions.www.war_attach_photos": [99, "enabled"], "contributions.www.war_compose_recent_photos": [102, "enabled"], "contributions.www.war_compose_redesign": [6, "enabled"], "contributions.www.war_compose_signup": [148, "disabled"], "eat24_free_delivery_banner": [45, "disabled"], "lsmoney.www.yg_raq_cards_on_search": [152, "status_quo"], "lower_promoted_delivery_threshold": [58, "reduced_to_fifteen"], "lsat.www.dropdown_header": [54, "enabled"], "lsm.www.unpakt_cta_change": [108, "unpakt_cta_enabled"], "messaging.www.composer_notifications_spam_and_hover_state": [177, "notifications_enabled"], "messaging.www.raq_cards_on_search": [61, "status_quo"], "messaging.www.yelp_guaranteed": [160, "status_quo"], "nowait_restaurant.www.no_wait_message": [106, "show_wait_or_get_in_line_copy"], "pagelet_mode_www_biz_details": [24, "allow_async"], "payment.ux.www": [197, "enabled"], "platform_pickup_filter": [20, "enabled"], "readerx.web.biz_for_services": [116, "biz_status_quo"], "readerx.web.popular_dishes": [198, "highlights_popular_dishes"], "review_actions_dropdown": [2, "disabled"], "searchux.www.services_serp_card_new_layout_v0_0": [151, "status_quo"], "styleguide_buttons": [13, "status_quo"], "styleguide_typography": [159, "status_quo"], "txn.www.checkout_page_changes": [135, "enabled"], "www_biz_details_raq_sticky": [84, "enabled"], "www_current_location_suggestion": [185, "enabled"], "www_second_page_pitch": [111, "status_quo"], "www_signup_redesign": [92, "status_quo"], "yelp.www.biz_details.lazy_loading.enabled": [25, "false"], "ytp_delivery_landing": [125, "platform_pages"], "ytp_eat24_yelp_style_to_iframe": [136, "enabled"], "ytp_order_confirmation_page": [143, "enabled"], "www_search_snippets_in_sync_with_ads": [112, "status_quo_8"], "yr_diner.www.direct_checkout_for_exact_match": [163, "disabled"]}}, "domain": "yelp.com", "enable_high_volume_events": false, "ga_enabled": true, "js_dimensions": {"global": {}, "www": {"js_vertical_search_type": [39, null], "platform_order_type": [127, null]}}, "metrics": {"global": {}, "www": {}}, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "user_id": null},null);
#             })();
#     </script>
# <script async="" charset="UTF-8" data-document-language="true" data-domain-script="5fbcd417-fbc1-4fcc-abad-f622f1bba72d" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script>
#             window.yelp = window.yelp || {};
#             window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#         </script>
# <script>        (function (d, w) {
#             if (('ontouchstart' in w) || w.DocumentTouch && d instanceof w.DocumentTouch){
#                 var html = d.getElementsByTagName("html")[0];
#                 html.classList.add("touch");
#             }
#         }(document, window));
# </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="width=1224" name="viewport"/>
# <meta content="Yelp" name="application-name"/>
# <meta content="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b8f6d9d556d5/ico/win8-tile.png" name="msapplication-TileImage"/>
# <meta content="#c41200" name="msapplication-TileColor"/>
# <meta content="https://www.yelp.com/" name="msapplication-starturl"/>
# <meta content="#c41200" name="msapplication-navbutton-color"/>
# <meta content="width=1024;height=768" name="msapplication-window"/>
# <meta content="Go to Yelp.com" name="msapplication-tooltip"/>
# <meta content="name=Find Reviews; action-uri=/; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <meta content="name=Hot New Businesses; action-uri=/openings; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <meta content="name=Yelp Deals; action-uri=/search?find_desc=deals; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <link href="android-app://com.yelp.android/yelp-app-indexing/biz/YZs1gNSh_sN8JmN_nrpxeA?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/>
# <link href="ios-app://284910350/yelp//biz/YZs1gNSh_sN8JmN_nrpxeA?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/>
# <meta content="Yelp" property="al:ios:app_name"/>
# <meta content="284910350" property="al:ios:app_store_id"/>
# <meta content="https://www.yelp.com/biz/terry-blacks-barbecue-austin?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple" property="al:ios:url"/>
# <link content="#c41200" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/4374c8fd03d1/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/118ff475a341/assets/img/logos/favicon.ico" rel="shortcut icon"/>
# <link href="https://m.yelp.com/biz/terry-blacks-barbecue-austin" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta name="critical_css_middleware"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-Regular.yji-1d0e82fb8ca5092d63b501cb78a3fcc5.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-SemiBold.yji-64284230686011de275c4b1bb4039f54.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-Bold.yji-49e6b3bb7a2df2996d09b9cdd89cf166.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/Poppins-Black.yji-5da432f73e49ed35ecf6e652010d4ee0.woff2" rel="preload" type="font/woff2"/>
# <script>
#     window.yelp = window.yelp || {};
#     window.yelp.critical_css_onload = function (id) {
#         this.removeAttribute("onload");
#         var el = document.querySelector('style[data-critical-css="' + id + '"]');
#         el.parentNode.removeChild(el);
#         this.rel = "stylesheet";
#     };
# </script>
# <meta id="emotion-container"/><meta id="emotion-container"/><style data-emotion-css="5r1d0t 1mpk29p 1g3e5b2 ardur y1jj6m 12anxc3 19sk4h4 8yg8ez 7vz7be n6i4z7">.css-5r1d0t{font-family:'Open Sans','Helvetica Neue',Helvetica,Arial,sans-serif;-webkit-text-decoration:none;text-decoration:none;color:rgba(0,131,143,1);font-size:14px;line-height:20px;}.css-5r1d0t:hover{-webkit-text-decoration:underline;text-decoration:underline;}.css-1mpk29p{width:24px;height:24px;display:inline-block;vertical-align:middle;position:relative;overflow:hidden;top:-0.1em;fill:rgba(43,39,60,1);}.css-1mpk29p::before{position:absolute;display:block;left:0;}.css-1mpk29p::after{content:'';display:block;position:absolute;left:0;right:0;top:0;bottom:0;}.css-1mpk29p svg{position:absolute;width:100%;height:100%;fill:inherit;display:block;left:0;top:0;right:0;bottom:0;}.css-1g3e5b2{-webkit-text-decoration:none;text-decoration:none;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-appearance:none;-moz-appearance:none;appearance:none;background-image:none;background-repeat:no-repeat;border:0;border-radius:4px;box-shadow:none;box-sizing:border-box;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;cursor:pointer;height:40px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding-bottom:8px;padding-left:16px;padding-right:16px;padding-top:8px;position:relative;text-align:center;-webkit-transition:all 0.8s;transition:all 0.8s;-webkit-transition-property:background-image,background-color,background-position,background-size,border-color,box-shadow,opacity;transition-property:background-image,background-color,background-position,background-size,border-color,box-shadow,opacity;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;width:auto;background-color:transparent;border:1px solid rgba(187,186,192,1);color:rgba(43,39,60,1);background-position:calc(var(--mousedown-x) - calc(var(--button-width,100px) * 200) / 2) calc(var(--mousedown-y) - calc(var(--button-width,100px) * 200) / 2);background-size:calc(var(--button-width,100px) * 200) calc(var(--button-width,100px) * 200);}.css-1g3e5b2:active,.css-1g3e5b2:focus,.css-1g3e5b2:hover,.css-1g3e5b2:visited{-webkit-text-decoration:none;text-decoration:none;}.css-1g3e5b2:disabled{background-color:rgba(238,238,239,1);background-image:none;border-color:rgba(238,238,239,1);box-shadow:none;color:rgba(187,186,192,1);outline:none;pointer-events:none;-webkit-transition:none;transition:none;}.css-1g3e5b2:hover{box-shadow:0 1px 4px 0 rgba(0,0,0,0.3);}.css-1g3e5b2:focus{box-shadow:0 0 4px 1px rgba(0,0,0,0.35);outline:none;}@media only screen and (max-width:599px){.responsive .css-1g3e5b2{box-shadow:none;font-weight:normal;}}@media only screen and (max-width:780px){.responsive-biz .css-1g3e5b2{box-shadow:none;font-weight:normal;}}@media (pointer:coarse){.css-1g3e5b2:hover{box-shadow:none;}}.css-1g3e5b2 + a{display:inline-block;margin-left:12px;vertical-align:middle;}.css-1g3e5b2 + a:not(.css-1g3e5b2),.css-1g3e5b2 + .button-sibling:not(.css-1g3e5b2){font-size:14px;line-height:1.28571em;margin-bottom:7px;margin-top:9px;}@media only screen and (max-width:599px){.responsive .css-1g3e5b2 + a:not(.css-1g3e5b2),.responsive .css-1g3e5b2 + .button-sibling:not(.css-1g3e5b2){font-size:16px;line-height:1.31250em;}}.ie .css-1g3e5b2 > span{display:block;position:relative;}.css-1g3e5b2:active{color:rgba(43,39,60,1);}.css-1g3e5b2:disabled{background-color:transparent;border:1px solid rgba(207,206,213,1);}.css-1g3e5b2:focus{background-color:rgba(0,0,0,0.12);}.css-1g3e5b2:hover{background-color:rgba(0,0,0,0.12);color:rgba(43,39,60,1);box-shadow:none;}.css-1g3e5b2[data-activated='true']{background-color:rgba(0,0,0,0.12);background-image:radial-gradient(rgba(0,0,0,0.05) 1%,transparent 1%);}.css-1g3e5b2[data-activated='true']:active{-webkit-transition ...
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-89529094a472499f5359.chunk.css" media="all" rel="stylesheet" type="text/css"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-8553a797f80748b46749.chunk.css" media="all" rel="stylesheet" type="text/css"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-7c4acc2cf053c9265937.chunk.css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if (IE 9)|(lt IE 9) ]> <link rel="stylesheet" type="text/css" media="all" href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/0547c86a37db/www-pkg-main.css">
#             <link rel="stylesheet" type="text/css" media="all" href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/4df7a42c19fb/www-pkg-more.css"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <link href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/4277ac50b3f0/www-pkg.css" media="all" rel="stylesheet" type="text/css"/> <!--<![endif]-->
# <link as="style" data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-f1220e1f35c9aed79322.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-1bfe0c140101c5f3454e.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-CollectionCardCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-d3daa33de6109baed24d.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-23559afa6b255bc7ae4f.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-209dcc516156687f98d4.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-72b88d09d7327326cf19.chunk.css" rel="preload"/>
# <link as="style" data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-de7739de9bd57b0ced69.chunk.css" rel="preload"/>
# <link as="style" data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-c8fa08eeb91f3579d49b.chunk.css" rel="preload"/>
# <link as="style" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-5cb154e1f1ba59637640.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-486cfbaafb47f9bfcf96.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-98b579b490c16cf65e53.chunk.css" rel="preload"/>
# <link as="script" data-chunk="ClaimReminderGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-c2a3318e5ea72dd581b7.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-5d7ecb57f6d808f2486f.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-381a6f1095432f111de1.chunk.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-db9543d312f3c6ec8804.chunk.js" rel="preload"/>
# <link as="script" data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-e50de536bc57c8b40313.chunk.js" rel="preload"/>
# <link as="script" data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-0690910be724dc43fad4.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-5c35b7d47c09e9bc118e.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-b2a71c9996b49779c9db.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-ba42035f2a6df453a4f7.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-CollectionCardCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-474473af3615347cf78d.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-CollectionCardCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-a9c32aaeda0d8209e916.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-4cdd5dc8c5500fb3bcc0.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-SEOLinks" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-4f41d2386f7054c64ebe.chunk.js" rel="preload"/>
# <link as="script" data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-806d89aa9cb460290904.chunk.js" rel="preload"/><link data-chunk="components-BizPageConfigurableAlertsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-98b579b490c16cf65e53.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-ServiceUpdateSummaryGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-486cfbaafb47f9bfcf96.chunk.css" rel="stylesheet"/>
# <link data-chunk="OnTheMenuGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-5cb154e1f1ba59637640.chunk.css" rel="stylesheet"/>
# <link data-chunk="MapBoxV2GQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-c8fa08eeb91f3579d49b.chunk.css" rel="stylesheet"/>
# <link data-chunk="BizHoursGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-de7739de9bd57b0ced69.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-MoreBusinessInfo" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-72b88d09d7327326cf19.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-BizQuestionsGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-209dcc516156687f98d4.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-Reviews" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-23559afa6b255bc7ae4f.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-CollectionCardCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-d3daa33de6109baed24d.chunk.css" rel="stylesheet"/>
# <link data-chunk="components-RelatedBusinessesCarousel" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-1bfe0c140101c5f3454e.chunk.css" rel="stylesheet"/>
# <link data-chunk="ClaimStatusGQL" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-f1220e1f35c9aed79322.chunk.css" rel="stylesheet"/><link data-rh="true" href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/><link data-rh="true" href="https://www.facebook.com/yelp" id="sitelink-profile-facebook" itemprop="sameAs"/><link data-rh="true" href="https://twitter.com/yelp" id="sitelink-profile-twitter" itemprop="sameAs"/><link data-rh="true" href="https://www.linkedin.com/company/31517" id="sitelink-profile-linkedin" itemprop="sameAs"/><link data-rh="true" href="https://instagram.com/yelp" id="sitelink-profile-instagram" itemprop="sameAs"/><link data-rh="true" href="https://www.yelp.com" id="sitelink" itemprop="url"/><link data-rh="true" href="https://www.yelp.com/biz/terry-blacks-barbecue-austin" rel="canonical"/><link data-rh="true" href="https://de.yelp.ch/biz/terry-blacks-barbecue-austin" hreflang="de-ch" rel="alternate"/><link data-rh="true" href="https://www.yelp.com.au/biz/terry-blacks-barbecue-austin" hreflang="en-au" rel="alternate"/><link data-rh="true" href="https://www.yelp.no/biz/terry-blacks-barbecue-austin" hreflang="nb-no" rel="alternate"/><link data-rh="true" href="https://fr.yelp.ca/biz/terry-blacks-barbecue-austin" hreflang="fr-ca" rel="alternate"/><link data-rh="true" href="https://fil.yelp.com.ph/biz/terry-blacks-barbecue-austin" hreflang="fil-ph" rel="alternate"/><link data-rh="true" href="https://www.yelp.co.jp/biz/terry-blacks-barbecue-austin" hreflang="ja-jp" rel="alternate"/><link data-rh="true" href="https://ms.yelp.my/biz/terry-blacks-barbecue-austin" hreflang="ms-my" rel="alternate"/><link data-rh="true" href="https://en.yelp.ch/biz/terry-blacks-barbecue-austin" hreflang="en-ch" rel="alternate"/><link data-rh="true" href="https://www.yelp.com.br/biz/terry-blacks-barbecue-austin" hreflang="pt-br" rel="alternate"/><link data-rh="true" href="https://www.yelp.pt/biz/terry-blacks-barbecue-austin" hreflang="pt-pt" rel="alternate"/><link data-rh="true" href="https://en.yelp.com.hk/biz/terry-blacks-barbecue-austin" hreflang="en-hk" rel="alternate"/><link data-rh="true" href="https://www.yelp.es/biz/terry-blacks-barbecue-austin" hreflang="es-es" rel="alternate"/><link data-rh="true" href="https://en.yelp.my/biz/terry-blacks-barbecue-austin" hreflang="en-my" rel="alternate"/><link data-rh="true" href="https://www.yelp.co.uk/biz/terry-blacks-barbecue-austin" hreflang="en-gb" rel="alternate"/><link data-rh="true" href="https://fr.yelp.be/biz/terry-blacks-barbecue-austin" hreflang="fr-be" rel="alternate"/><link data-rh="true" href="https://it.yelp.ch/biz/terry-blacks-barbecue-austin" hreflang="it-ch" rel="alternate"/><link data-rh="true" href="https://www.yelp.de/biz/terry-blacks-barbecue-austin" hreflang="de-de" rel="alternate"/><link data-rh="true" href="https://www.yelp.nl/biz/terry-blacks-barbecue-austin" hreflang="nl-nl" rel="alternate"/><link data-rh="true" href="https://www.yelp.cz/biz/terry-blacks-barbecue-austin" hreflang="cs-cz" rel="alternate"/><link data-rh="true" href="https://www.yelp.at/biz/terry-blacks-barbecue-austin" hreflang="de-at" rel="alternate"/><link data-rh="true" href="https://www.yelp.cl/biz/terry-blacks-barbecue-austin" hreflang="es-cl" rel="alternate"/><link data-rh="true" href="https://zh.yelp.com.hk/biz/terry-blacks-barbecue-austin" hreflang="zh-hk" rel="alternate"/><link data-rh="true" href="https://www.yelp.ie/biz/terry-blacks-barbecue-austin" hreflang="en-ie" rel="alternate"/><link data-rh="true" href="https://www.yelp.com.ar/biz/terry-blacks-barbecue-austin" hreflang="es-ar" rel="alternate"/><link data-rh="true" href="https://www.yelp.com.sg/biz/terry-blacks-barbecue-austin" hreflang="en-sg" rel="alternate"/><link data-rh="true" href="https://www.yelp.fr/biz/terry-blacks-barbecue-austin" hreflang="fr-fr" rel="alternate"/><link data-rh="true" href="https://www.yelp.it/biz/terry-blacks-barbecue-austin" hreflang="it-it" rel="alterna ...
# <script>/*! loadCSS. [c]2017 Filament Group, Inc. MIT License */
# (function(a){if(!a.loadCSS){a.loadCSS=function(){}}var b=loadCSS.relpreload={};b.support=(function(){var d;try{d=a.document.createElement("link").relList.supports("preload")}catch(f){d=false}return function(){return d}})();b.bindMediaToggle=function(e){var f=e.media||"all";function d(){e.media=f}if(e.addEventListener){e.addEventListener("load",d)}else{if(e.attachEvent){e.attachEvent("onload",d)}}setTimeout(function(){e.rel="stylesheet";e.media="only x"
# });setTimeout(d,3000)};b.poly=function(){if(b.support()){return}var d=a.document.getElementsByTagName("link");for(var e=0;e<d.length;e++){var f=d[e];if(f.rel==="preload"&&f.getAttribute("as")==="style"&&!f.getAttribute("data-loadcss")){f.setAttribute("data-loadcss",true);b.bindMediaToggle(f)}}};if(!b.support()){b.poly();var c=a.setInterval(b.poly,500);if(a.addEventListener){a.addEventListener("load",function(){b.poly();a.clearInterval(c)})}else{if(a.attachEvent){a.attachEvent("onload",function(){b.poly();
# a.clearInterval(c)})}}}if(typeof exports!=="undefined"){exports.loadCSS=loadCSS}else{a.loadCSS=loadCSS}}(typeof global!=="undefined"?global:this));</script>
# <script></script>
# <script>            document.cookie = "xcj=1|aOsizkwGCHD0v-VT6fDGb5d_Txfz8HoOvZxwM91qiK0; Domain=.yelp.com; expires=Fri, 27 Aug 2021 10:51:42 GMT; Max-Age=7776000; Path=/";
# </script>
# </head>
# <body class="jquery country-us logged-out react-modal-body u-bg-color-white v2" id="yelp_main_body">
# <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "61ba06c815ef134d66c4ea4d43a5a235a05aed31", "metaData": {"projectName": "yelp_main"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1.0}, "apiKey": "ac0c27867d3912ce5714ff131041af4f", "enabled": true}</script>
# <script>            window.pageSpeedCustomTimestamps['body:start'] = (new Date()).getTime();
# </script>
# <div id="fb-root"></div>
# <div class="lang-en" id="wrap">
# <div class="page-header">
# <yelp-react-root><div data-hypernova-id="efe408a5-c4eb-406f-9a25-619481bd5bce" data-hypernova-key="yelp_main__61ba06c815ef134d66c4ea4d43a5a235a05aed31__yelp_main__ConsumerHeader__dynamic"><div class="border-color--default__373c0__2oFDT"><div class="consumer-header-container__373c0__lbNbB border--bottom__373c0__uPbXS border-color--default__373c0__2oFDT background-color--white__373c0__GVEnp"><div class="consumer-header__373c0__Qzfd9 border-color--default__373c0__2oFDT"><div class="arrange__373c0__UHqhV vertical-align-middle__373c0__2TQsQ border-color--default__373c0__2oFDT"><div class="logo-arrange-unit__373c0__2SvbP arrange-unit__373c0__1piwO border-color--default__373c0__2oFDT"><div class="margin-r4__373c0__398s1 margin-sm-r0__373c0__3Oak_ border-color--default__373c0__2oFDT"><div class="logo__373c0__3xbyt logo-image__373c0__2MtBx logo-container__373c0__2d_nu border-color--default__373c0__2oFDT" data-analytics-label="logo" id="logo"><a class="logo-link__373c0__1l5qC css-5r1d0t" href="/" name="" rel="" role="link" target="">Yelp</a></div></div></div><div class="search-suggest-arrange-unit__373c0__1r2IG arrange-unit__373c0__1piwO arrange-unit-fill__373c0__17z0h border-color--default__373c0__2oFDT"><div class="search-suggest-container-outer__373c0__9lfvS border-color--default__373c0__2oFDT"><div class="search-suggest-container-inner__373c0__2pXbM border-color--default__373c0__2oFDT"><div class="arrange__373c0__UHqhV gutter-2__373c0__3Zpeq border-color--default__373c0__2oFDT"><div class="arrange-unit__373c0__1piwO arrange-unit-fill__373c0__17z0h border-color--default__373c0__2oFDT"><div class="search-suggest__373c0__31JJZ"><div class=""><form action="/search" class="find-near-form__373c0__QkXpc" id="header_find_form" method="get" role="search"><div class="undefined arrange__373c0__UHqhV border-color--default__373c0__2oFDT"><div class="arrange-unit__373c0__1piwO arrange-unit-fill__373c0__17z0h border-color--default__373c0__2oFDT"><div class="find-near-arrange__373c0__dhora arrange__373c0__UHqhV layout-equal__373c0__2jcUj border-color--default__373c0__2oFDT"><div class="find-near-arrange-unit__373c0__1x8M9 arrange-unit__373c0__1piwO border-color--default__373c0__2oFDT"><label class="label__373c0__2kYNn pseudo-input__373c0__5zGeH pseudo-input__373c0__3aR8D pseudo-input--find-near__373c0__2MkBe pseudo-input--find__373c0__tF4yY" for="search_description"><span class="pseudo-input-text__373c0__1Waqo display--inline__373c0__1DbOG border-color--default__373c0__2oFDT"><div class="pseudo-input-icon-container__373c0__2jsaM margin-r1-5__373c0__1Vie3 border-color--default__373c0__2oFDT"><span aria-hidden="false" aria-label="Find" class="icon--24-search-v2 pseudo-input-icon__373c0__1e_Dt css-1mpk29p"><svg class="icon_svg" height="24" width="24"><path d="M21.853 20.355l-3.444-3.443a9.428 9.428 0 10-16.761-6.171 9.428 9.428 0 0015.348 7.586l3.443 3.442a1 1 0 101.414-1.414zM5.82 16.245a7.429 7.429 0 115.253 2.175 7.38 7.38 0 01-5.253-2.176z"></path></svg></span></div></span><div class="border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"><div class="typeahead__373c0__HGjy7 border-color--default__373c0__2oFDT"><input aria-hidden="true" autocomplete="off" class="input__373c0__1kQwh input__373c0__3GvbQ hidden-input__373c0__3qUuQ" disabled="" placeholder=" " spellcheck="false" tabindex="-1" type="text" value=""/><input aria-autocomplete="list" autocomplete="off" class="input__373c0__1kQwh input__373c0__3GvbQ original-input__373c0__3YWBR" data-testid="suggest-desc-input" id="search_description" name="find_desc" placeholder="tacos, cheap dinner, Max’s" tabindex="0" type="text" value=""/></div></div></label></div><div class="responsive-gutter__373c0__1mEC1 location-arrange-unit__373c0__O8Ilj find-near-arrange-unit__373c0__1x8M9 arrange-unit__373c0__1piwO layout-stack-gutter-1-5__373c0__3a0i4 margin-sm-t1-5__373c0__1bZ_H border-color--default__373c0__2oFDT"><label class="label__373c0__2kYNn pseudo-input__373c0__5zGeH pseudo-input__373c0__3aR ...
# <script data-hypernova-id="efe408a5-c4eb-406f-9a25-619481bd5bce" data-hypernova-key="yelp_main__61ba06c815ef134d66c4ea4d43a5a235a05aed31__yelp_main__ConsumerHeader__dynamic" type="application/json"><!--{"holidayModifier":null,"locale":"en_US","uniqueRequestId":"7366194a9732fea9","messages":{" and ":" and "," and let us know if you think the content you’ve reported may violate these guidelines.":" and let us know if you think the content you’ve reported may violate these guidelines.","%{businessName} accepts %{paymentAttributesToDisplay}.":"%{businessName} accepts %{paymentAttributesToDisplay}.","%{businessName} also recommends":"%{businessName} also recommends","%{businessName} has %{businessRating} stars.":"%{businessName} has %{businessRating} stars.","%{businessName} is a Yelp advertiser.":"%{businessName} is a Yelp advertiser.","%{businessName} is open %{daysOpenToDisplay}.":"%{businessName} is open %{daysOpenToDisplay}.","%{businessOwnerRole} of %{businessName}":"%{businessOwnerRole} of %{businessName}","%{confirmedDay} at %{confirmedTime}":"%{confirmedDay} at %{confirmedTime}","%{coverCount} person||||%{coverCount} people":"%{coverCount} person||||%{coverCount} people","%{currentNumberLicense} of %{totalNumberLicense}":"%{currentNumberLicense} of %{totalNumberLicense}","%{current_page} of %{total_pages}":"%{current_page} of %{total_pages}","%{minWait} - %{maxWait} mins":"%{minWait} - %{maxWait} mins","%{number} of %{total}":"%{number} of %{total}","%{price}/hr":"%{price}/hr","%{rating} star rating":"%{rating} star rating","%{smart_count} More Attribute||||%{smart_count} More Attributes":"%{smart_count} More Attribute||||%{smart_count} More Attributes","%{smart_count} Photo||||%{smart_count} Photos":"%{smart_count} Photo||||%{smart_count} Photos","%{smart_count} Place||||%{smart_count} Places":"%{smart_count} Place||||%{smart_count} Places","%{smart_count} Review||||%{smart_count} Reviews":"%{smart_count} Review||||%{smart_count} Reviews","%{smart_count} Update||||%{smart_count} Updates":"%{smart_count} Update||||%{smart_count} Updates","%{smart_count} other review that is not currently recommended||||%{smart_count} other reviews that are not currently recommended":"%{smart_count} other review that is not currently recommended||||%{smart_count} other reviews that are not currently recommended","%{smart_count} person found this helpful||||%{smart_count} people found this helpful":"%{smart_count} person found this helpful||||%{smart_count} people found this helpful","%{smart_count} recommended review||||%{smart_count} recommended reviews":"%{smart_count} recommended review||||%{smart_count} recommended reviews","%{smart_count} review mentioning “%{query}”||||%{smart_count} reviews mentioning “%{query}”":"%{smart_count} review mentioning “%{query}”||||%{smart_count} reviews mentioning “%{query}”","%{smart_count} review that is not currently recommended||||%{smart_count} reviews that are not currently recommended":"%{smart_count} review that is not currently recommended||||%{smart_count} reviews that are not currently recommended","%{smart_count} review||||%{smart_count} reviews":"%{smart_count} review||||%{smart_count} reviews","%{smart_count} violation: %{description}||||%{smart_count} violations: %{description}":"%{smart_count} violation: %{description}||||%{smart_count} violations: %{description}","%{username} said":"%{username} said","%{waitlistClosedTimeText}":"%{waitlistClosedTimeText}","(111) 111-1111":"(111) 111-1111","(Optional)":"(Optional)","(Optional) Any more details you'd like to share ?":"(Optional) Any more details you'd like to share ?","(no rating)":"(no rating)","*":"*","+%{smart_count} Popular Dish||||+%{smart_count} Popular Dishes":"+%{smart_count} Popular Dish||||+%{smart_count} Popular Dishes",", ":", ","0 mins":"0 mins","1 hour":"1 hour","1 truck":"1 truck","2 hours":"2 hours","2 movers":"2 movers","3 hours":"3 hours","4 or more":"4 or more","4 or more hours":"4 or more hours","<0&gt;<1&gt;<2/&gt;</1& ...
# <script nonce="7366194a">
#             (function() {
#                 var main = null;
#
#                 var main=(function(){function a(b){window.yDFP.ABP={};window.yDFP.ABP.getPixelSource=function(c){return b+"?ch="+c+"&rn="+Math.random()*11};window.yDFP.ABP.detect=function(l){var g=false;var f=2;var i=false;var h=false;function k(n,m){if(f===0||m>400){n(f===0&&g)}else{setTimeout(function(){k(n,m*2)},m*2)}}function j(){if(f!==0){return}g=!i&&h}var e=function(){f-=1;j()};var d=new Image();d.onload=e;d.onerror=function(){i=true;e()};d.src=window.yDFP.ABP.getPixelSource(1);var c=new Image();c.onload=e;
# c.onerror=function(){h=true;e()};c.src=window.yDFP.ABP.getPixelSource(2);k(l,100)};window.yDFP.ABP.abpInstalledChannel="1382551876";window.yDFP.ABP.abpNotInstalledChannel="2859285073"}window.yDFP=window.yDFP||{};window.yDFP.initABPDetection=a;return window.yDFP.initABPDetection})();
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("/px.gif");
#             })();
#     </script>
# <div id="print-masthead">
# <img alt="Yelp" class="print-bkg-img" src="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b7e9d647188d/gfx/header_print.gif"/>
# </div>
# </div>
# <span class="offscreen" id="page-content"> </span>
# <div class="main-content-wrap main-content-wrap--full">
# ...
# </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[0, 33, 2, 4, 5, 6, 7, 9, 14, 16, 18, 23, 26, 30, 31]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks": ["components-MoreBusinessInfo", "components-ServiceUpdateSummaryGQL", "components-CollectionCardCarousel", "components-Reviews", "ClaimReminderGQL", "components-RelatedBusinessesCarousel", "components-BizQuestionsGQL", "ClaimStatusGQL", "MapBoxV2GQL", "OnTheMenuGQL", "components-SEOLinks", "components-BizPageConfigurableAlertsGQL", "BizHoursGQL"]}</script><script async="" data-chunk="ClaimReminderGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-c2a3318e5ea72dd581b7.chunk.js"></script>
# <script async="" data-chunk="components-BizPageConfigurableAlertsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-5d7ecb57f6d808f2486f.chunk.js"></script>
# <script async="" data-chunk="components-ServiceUpdateSummaryGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-ServiceUpdateSummaryGQL.yji-381a6f1095432f111de1.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-db9543d312f3c6ec8804.chunk.js"></script>
# <script async="" data-chunk="MapBoxV2GQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-e50de536bc57c8b40313.chunk.js"></script>
# <script async="" data-chunk="BizHoursGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-0690910be724dc43fad4.chunk.js"></script>
# <script async="" data-chunk="components-MoreBusinessInfo" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-5c35b7d47c09e9bc118e.chunk.js"></script>
# <script async="" data-chunk="components-BizQuestionsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-b2a71c9996b49779c9db.chunk.js"></script>
# <script async="" data-chunk="components-Reviews" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-ba42035f2a6df453a4f7.chunk.js"></script>
# <script async="" data-chunk="components-CollectionCardCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-474473af3615347cf78d.chunk.js"></script>
# <script async="" data-chunk="components-CollectionCardCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-a9c32aaeda0d8209e916.chunk.js"></script>
# <script async="" data-chunk="components-RelatedBusinessesCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-4cdd5dc8c5500fb3bcc0.chunk.js"></script>
# <script async="" data-chunk="components-SEOLinks" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-4f41d2386f7054c64ebe.chunk.js"></script>
# <script async="" data-chunk="ClaimStatusGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-806d89aa9cb460290904.chunk.js"></script>
# <script>            window.yelp = window.yelp || {};
#             window.yelp.reactRenderMode = "legacy";
# </script>
# <script crossorigin="anonymous" integrity="sha384-FbHUaR69a828hqWjPw4PFllFj1bvveKOTWORGkyosCw720HXy/56+2hSuQDaogMb" nonce="7366194a" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/6fef55c62df3/assets/vendor/babel-polyfill/6.23.0/polyfill.min.js"></script><script nonce="7366194a">
#         yConfig = window.yConfig || {};
#         yConfig.vendorExternalURLs = yConfig.vendorExternalURLs || {};
#         </script><script crossorigin="anonymous" integrity="sha384-qn+ML/QkkJxqn4LLs1zjaKxlTg2Bl/6yU/xBTJAgxkmNGc6kMZyeskAG0a7eJBR1" nonce="7366194a" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/f808b8e8ab51/assets/vendor/react/16.8.6/umd/react.production.min.js"></script><script crossorigin="anonymous" integrity="sha384-85IMG5rvmoDsmMeWK/qUU4kwnYXVpC+o9hoHMLi4bpNR+gMEiPLrvkZCgsr7WWgV" nonce="7366194a" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/fad5842bd019/assets/vendor/react-dom/16.8.6/umd/react-dom.production.min.js"></script><script crossorigin="anonymous" nonce="7366194a" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp_main_webpack_runtime.yji-c60247a61dcb613c867d.js"></script><script crossorigin="anonymous" nonce="7366194a" src="https://s3-media0.fl.yelpcdn.com/assets/public/common_chunk.yji-23a8233d4b3b4e75e4f7.chunk.js"></script><script crossorigin="anonymous" nonce="7366194a" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_core.yji-2358b416cbd24ecdd677.chunk.js"></script><script crossorigin="anonymous" nonce="7366194a" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_misc_react.yji-084f82900bbb5eccb098.chunk.js"></script><script crossorigin="anonymous" nonce="7366194a" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_react_biz_details_v2.yji-bb765081a7773588dcb4.chunk.js"></script><script nonce="7366194a">
#                 yConfig.vendorExternalURLs["plugin-detect"]=['https://s3-media0.fl.yelpcdn.com/assets/2/www/js/bfd62b330c7a/assets/vendor_external/plugin-detect-0.6.3.min.js']
#
#                 yConfig.vendorExternalURLs["fast-click"]=['https://s3-media0.fl.yelpcdn.com/assets/2/www/js/960df06ce458/assets/vendor_external/fastclick.min.js']
#                 yelp.www.pages.initSitrep(true);
# yelp.www.pages.initBugsnag();
# window.YelpReactConsumerHeader.hydrateReactComponent();
# window.YelpReactBizDetailsV2.hydrateReactComponents();
# window.PageSpeedLogging.initBunsenLogging("biz_details#default");
# window.logBunsenPageview("biz_details#default", "biz");
# </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 main = function (serviceName, sha) {window.yelp_react = {serviceName: serviceName,sha: sha};};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("yelp_main.www","61ba06c815ef134d66c4ea4d43a5a235a05aed31");
#             })();
#     </script>
# <script>                window.webLogInfo = true;
# </script>
# <script>                window.yClientLogInfo = true;
# </script>
# <script nonce="7366194a">
#             (function() {
#                 var main = null;
#
#                 var main=function(){if(["iPhone","iPod","iPad"].indexOf(navigator.platform)===-1||!window.requestAnimationFrame){return}window.bannerDetectionInitialScroll=window.bannerDetectionInitialScroll||window.scrollY||-100;requestAnimationFrame(function(){window.scrollTo(0,-100);requestAnimationFrame(function(){window.scrollBy(0,1);requestAnimationFrame(function(){window.userHasYelpApp=!window.scrollY;window.scrollTo(0,window.bannerDetectionInitialScroll)})})})};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <script nonce="7366194a">
#             (function() {
#                 var main = null;
#
#                 var main=function loadSpice(i){var l=0;var m=1;var j=2;var g="0";var k="1";var n=function(){if(document.querySelector){return document.querySelector(".delay-spice")}var o=document.getElementsByTagName("div");var r=o.length;var q=new RegExp("(^|\\s)delay-spice(\\s|$)");for(var p=0;p<r;++p){if(q.test(o[p].className)){return o[p]}}return null};function e(){return(window._gaUserPrefs&&window._gaUserPrefs["ioo"]&&typeof(window._gaUserPrefs["ioo"])==="function"&&window._gaUserPrefs["ioo"]()===true||false)?"1":"0"
# }function f(){var o=["__webdriver_evaluate","__selenium_evaluate","__webdriver_script_function","__webdriver_script_func","__webdriver_script_fn","__fxdriver_evaluate","__driver_unwrapped","__webdriver_unwrapped","__driver_evaluate","__selenium_unwrapped","__fxdriver_unwrapped",];var q=["_phantom","__nightmare","_selenium","callPhantom","callSelenium","_Selenium_IDE_Recorder",];var r=0;for(var p=0;p<q.length;p++){if(typeof window[q[p]]!=="undefined"){r+=1}}for(var p=0;p<o.length;p++){if(typeof window.document[o[p]]!=="undefined"){r+=1
# }}return r}function d(){if(typeof window.navigator.permissions!=="undefined"){var o=window.navigator.permissions;return(o.query.toString()!=="function query() { [native code] }"||o.query.toString.toString()!=="function toString() { [native code] }"||o.hasOwnProperty("query"))?1:0}return 2}function h(q,p){var r;if(p===l){r=["/ad_sp","ice?","r=",i]}else{r=["/sp","ice?","r=",i];if(p===j){r.push("&log_ad_spice=1")}}r.push("&pagevis="+q);r.push("&gablock="+e());if(window.webLogInfo&&"navigator" in window){r.push("&webdriver="+(("webdriver" in window.navigator&&window.navigator.webdriver)?1:0))
# }if(window.yClientLogInfo){if("navigator" in window){if(typeof window.navigator.languages!=="undefined"){r.push("&languages="+window.navigator.languages.length)}if(typeof window.navigator.plugins!=="undefined"){r.push("&plugins="+window.navigator.plugins.length)}}r.push("&chrome="+((!!window.chrome)?1:0));r.push("&permissionsSpoofed="+d());r.push("&headlessVarCount="+f())}var o=new Image();o.src=r.join("")}function b(o){if(n()){h(o,m);c(o)}else{h(o,j)}}function c(o){if(n()){window.setTimeout(function(){c(o)
# },500)}else{h(o,l)}}if(!document.webkitHidden){b(g)}else{var a=false;document.addEventListener("webkitvisibilitychange",function(){if(document.webkitHidden||a){return}a=true;b(k)})}};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("7366194a9732fea9");
#             })();
#     </script>
# <script>            yConfig.csrf = {"FacebookTokenRefresh": "d97ce97653ba4821fb41ce20b5016d1a7289d786e742992d5c059107db7f78f2"};
# </script>
# <div id="ttdUniversalPixelTag290e816a69e9439f960a9588bc2ffb54" style="display:none">
# <script src="https://js.adsrvr.org/up_loader.1.1.0.js" type="text/javascript"></script>
# <script nonce="7366194a">
#             (function() {
#                 var main = null;
#
#                 var main=function(){(function(b){if(typeof TTDUniversalPixelApi==="function"){var a=new TTDUniversalPixelApi();a.init("igcouad",["mvh4ai1"],"https://insight.adsrvr.org/track/up","ttdUniversalPixelTag290e816a69e9439f960a9588bc2ffb54")}})(this)};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# </div>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=102029836881428&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script nonce="7366194a">
#             (function() {
#                 var main = null;
#
#                 var main=function(){var c=Math.random()+"";var b=c*10000000000000;document.write('<iframe src="https://6372968.fls.doubleclick.net/activityi;src=6372968;type=invmedia;cat=qr3hlsqk;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord='+b+'?" width="1" height="1" frameborder="0" style="display:none"></iframe>')};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <noscript>
# <iframe frameborder="0" height="1" src="https://6372968.fls.doubleclick.net/activityi;src=6372968;type=invmedia;cat=qr3hlsqk;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord=1?" style="display:none" width="1"></iframe>
# </noscript>
# <script nonce="7366194a">
#             (function() {
#                 var main = null;
#
#                 var main=function(){var a=new Image(1,1);a.onerror=a.onload=function(){a.onerror=a.onload=null};a.src=["//secure-us.imrworldwide.com/cgi-bin/m?ci=us-804377h&cg=0&cc=1&si=",escape(window.location.href),"&rp=",escape(document.referrer),"&ts=compact&rnd=",(new Date()).getTime()].join("")};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <noscript>
# <img alt="" height="1" src="//secure-us.imrworldwide.com/cgi-bin/m?ci=us-804377h&amp;cg=0&amp;cc=1&amp;ts=noscript" width="1"/>
# </noscript>
# <script nonce="7366194a">
#             (function() {
#                 var main = null;
#
#                 var main=function(a){window.yelp_bunsen_logger.bunsen_logger.init(a)};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main({"context": [{"schema_id": 279661, "payload_data": {"guv": "D87908105FB7A418"}}, {"schema_id": 171864, "payload_data": {"unique_request_id": "6ae94d4d39a34842"}}, {"schema_id": 280941, "payload_data": {"internal_ip": false}}, {"schema_id": 338431, "payload_data": {"internal_ip": false}}, {"schema_id": 280599, "payload_data": {"language": "en", "country": "US"}}, {"schema_id": 338430, "payload_data": {"language": "en", "country": "US"}}, {"schema_id": 283288, "payload_data": {"user_id": null}}, {"schema_id": 311701, "payload_data": {"platform": "www"}}, {"schema_id": 338439, "payload_data": {"platform": "www"}}, {"schema_id": 284174, "payload_data": {"normed_app_version": null}}, {"schema_id": 284175, "payload_data": {"normed_device_type": "UnknownDevice"}}, {"schema_id": 312263, "payload_data": {"product": "consumer", "product_version": "r61ba06c815-deploy-unforgiven"}}, {"schema_id": 338440, "payload_data": {"product": "consumer", "product_version": "r61ba06c815-deploy-unforgiven"}}, {"schema_id": 309536, "payload_data": {"previous_unique_view_id": null, "unique_view_id": "7366194a9732fea9"}}, {"schema_id": 338432, "payload_data": {"previous_unique_view_id": null, "unique_view_id": "7366194a9732fea9"}}, {"schema_id": 311448, "payload_data": {"biz_user_id_encid": null}}, {"schema_id": 311702, "payload_data": {"os_name": "unknown", "os_version": "x.x.x"}}, {"schema_id": 338437, "payload_data": {"os_name": "unknown", "os_version": "x.x.x"}}, {"schema_id": 306745, "payload_data": {"name": "www"}}, {"schema_id": 311859, "payload_data": {"page_id": "271e5394aa81cc0c4d8c9858e967550de0b41870"}}, {"schema_id": 311757, "payload_data": {"is_interactive": true}}, {"schema_id": 338434, "payload_data": {"is_interactive": true}}, {"schema_id": 311510, "payload_data": {"user_id_encid": null}}, {"schema_id": 338441, "payload_data": {"user_id_encid": null}}, {"schema_id": 311758, "payload_data": {"interface_name": "python_requests", "interface_version": "2.24.x"}}, {"schema_id": 338435, "payload_data": {"interface_name": "python_requests", "interface_version": "2.24.x"}}, {"schema_id": 312281, "payload_data": {"offset": null}}, {"schema_id": 338436, "payload_data": {"offset": null}}, {"schema_id": 311756, "payload_data": {"hardware_model": null}}, {"schema_id": 338433, "payload_data": {"hardware_model": null}}, {"schema_id": 321983, "payload_data": {"user_advertising_id": null}}, {"schema_id": 352511, "payload_data": {"source": "yelp-main"}}]});
#             })();
#     </script>
# </body>
# </html>

# %% [markdown]
# ### Finding usernames of first 10 reviews

# %%
soup_username = soup_sub.select('.css-m6anxm .css-166la90')

username = []
for name in soup_username:
    username.append(name.string)
    
username[0:10]
# Out:
# ['Patricia N.',
#  'Kirstin N.',
#  'Ivy C.',
#  'Rayand G.',
#  'Abby P.',
#  'Dan S.',
#  'Billy Y.',
#  'Nancy L.',
#  'Desiree N.',
#  'Samira S.']

# %% [markdown]
# ### Finding ratings of first 10 reviews

# %%
# Get ratings
soup_stars=soup_sub.select('.margin-b1-5__373c0__2Wblx .overflow--hidden__373c0__2B0kz')

rating = []

for stars in soup_stars:
    rating.append(stars.attrs['aria-label'])

# Get rid of text "star rating"
rating  = [r[0:len(rating)][0] for r in rating]

#convert from string to number
rating = [float(i) for i in rating]

rating
# Out:
# [5.0, 5.0, 5.0, 5.0, 4.0, 1.0, 5.0, 5.0, 4.0, 5.0]

# %% [markdown]
# ### Find dates of first 10 reviews

# %%
#Get date of rating
soup_date=soup_sub.select('.margin-b1-5__373c0__2Wblx .css-e81eai')

date_review = []

for date in soup_date:
    date_review.append(date.string)

date_review
# Out:
# ['4/14/2021',
#  '4/15/2021',
#  '4/4/2021',
#  '5/23/2021',
#  '5/26/2021',
#  '5/23/2021',
#  '5/16/2021',
#  '5/9/2021',
#  '5/24/2021',
#  '5/6/2021']

# %% [markdown]
# ### Find text of first 10 reviews

# %%
html_texts=soup_sub.select('.css-n6i4z7 .raw__373c0__3rcx7')

html_text = []

for t in html_texts:
    html_text.append(t.get_text())

# View first example text
html_text[0]
# Out:
# "Absolutely delicious bbq. Hubby and I were driving through Austin on one of our road trips and we knew we had to get some Texas-style bbq. We were able to do an online preorder the previous day, and were lucky enough that they weren't super busy so that we were able to enjoy the bbq fresh on one of their picnic tables outside. Might be easier to do a bullet point for what we ordered and what we thought, so here goes!Meats:Beef ribs - These things are ginormous. You'll end up paying around $40.00 for one rib, but honestly this one rib is a full meal for one or can be shared by up to 3 people and will be enough meat for everyone to appreciate it. It was tender, super juicy, and just so satisfying. Pork ribs - Literally fell off the bone when I bit into it. The dry rub was fantastic. Honestly, you wouldn't need to add any bbq sauce because it's packed with flavor and juicy. Excellent choice. Cheese and jalapeño sausage - This is like a little treat. You can taste the spices used in the sausage, you get small chunks of gooey cheese, and the jalapeños added a nice subtle heat. Chopped brisket - Tasty, but my least favorite of the meat choices we ordered. It felt a little dry, and I wasn't sure if they doused it in their bbq like it was described on their menu. I ended up having to add more sauce. Maybe they used a leaner part of the brisket for this, so might be a good option if you're trying to watch your intake (but honestly if you're going to a bbq pit while on a strict diet, you're missing out - everything in moderation is ok!).Sliced brisket - Wow. The pièce de résistance of the entire meal. Best brisket ever. Tender, juicy, flavorful. The balance of lean meat and fat. I now wish I had ordered 5 pounds of this to take home, or even ordered one of their chilled whole briskets. This is the brisket of dreams. No joke, you have to try it. Sides:Cornbread - Great cornbread. It was moist, it had a nice nutty flavor to it. It's a nice sweet bite in between all the savory of the bbq. Coleslaw - I typically don't like coleslaw, but they do theirs well. Nice, chunky and crispy cabbage. The dressing wasn't too thick or too fatty. It's a nice refreshing bite to balance out all the fatty goodness from the bbq. We ordered a half pound of everything (that's the minimum allowed with their online ordering, not sure if you can order less in person), and one beef rib for two people. Definitely more than we could finish. What we ordered would be good for probably up to four adults and everybody would've been full. I can't wait to return to Austin so I can visit again!"

# %% [markdown]
# ### Get reviewer origin location

# %%
html_origin = soup_sub.select('.arrange-unit-fill__373c0__17z0h .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .css-n6i4z7')

soup_origin = []

for origin in html_origin:
    soup_origin.append(origin.get_text())

# View first example text
soup_origin
# Out:
# ['Jacksonville, FL',
#  'Salt Lake City, UT',
#  'Orange County, CA',
#  'Santa Maria, CA',
#  'West Covina, CA',
#  'Sacramento, CA',
#  'Cary, NC',
#  'Murrieta, CA',
#  'El Paso, TX',
#  'Williamsville, NY']

# %% [markdown]
# ### Get reviewer friend count

# %%
# Get friend count
soup_friends = soup_sub.select('.arrange-unit-fill__373c0__17z0h .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .icon--16-friends-v2+ .border-color--default__373c0__2oFDT .css-1dgkz3l')

friendcount = []

for friends in soup_friends:
    friendcount.append(friends.get_text())

#convert from string to number
friendcount = [float(i) for i in friendcount]

friendcount
# Out:
# [412.0, 29.0, 1735.0, 15.0, 0.0, 27.0, 21.0, 94.0, 666.0, 180.0]

# %% [markdown]
# ### Get reviewer review count

# %%
# Get review count
soup_reviews = soup_sub.select('.arrange-unit-fill__373c0__17z0h .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .border-color--default__373c0__2oFDT .icon--16-review-v2+ .border-color--default__373c0__2oFDT .css-1dgkz3l')
reviewcount = []

for reviews in soup_reviews:
    reviewcount.append(reviews.get_text())

#convert from string to number
reviewcount = [float(i) for i in reviewcount]

reviewcount
# Out:
# [358.0, 78.0, 575.0, 11.0, 7.0, 50.0, 108.0, 93.0, 176.0, 112.0]

# %% [markdown]
# ### Get reviewer picture count

# %%
# Get picture count
soup_pictures = soup_sub.select('.icon--16-photos-v2+ .border-color--default__373c0__2oFDT .css-1dgkz3l')

picturecount = []

for pictures in soup_pictures:
    picturecount.append(pictures.get_text())

#convert from string to number
picturecount = [float(i) for i in picturecount]

picturecount
# Out:
# [651.0, 204.0, 1410.0, 15.0, 22.0, 18.0, 303.0, 563.0, 875.0, 209.0]

# %% [markdown]
# ## Finding the user profile information
# Meaning the information that cannot be viewed immediately in their review

# %% [markdown]
# ### Finding the links

# %%
link_user = []

for userlink in soup_username:
        link_user.append(userlink.get('href'))

link_user=["https://www.yelp.com" + s for s in link_user]

link_user
# Out:
# ['https://www.yelp.com/user_details?userid=JY6IepgSDkESrtMl1GCD_Q',
#  'https://www.yelp.com/user_details?userid=KWoKuuL6m1zCCLLEc6IgBg',
#  'https://www.yelp.com/user_details?userid=pE_rKN0nhg1QRbr9dxiDew',
#  'https://www.yelp.com/user_details?userid=X4ov-Nb-cIgRFMY1q_kolQ',
#  'https://www.yelp.com/user_details?userid=nyE4-wjrH4iJEAgaXxBYtw',
#  'https://www.yelp.com/user_details?userid=BB20SM4_y6vKVB4mfnlZzA',
#  'https://www.yelp.com/user_details?userid=_4dx5wBsmyv4FAQ-6Qp_Lw',
#  'https://www.yelp.com/user_details?userid=FWVS68burzsuaavhBdc3qQ',
#  'https://www.yelp.com/user_details?userid=F4i7RdxvkfNRTDEHWARTMA',
#  'https://www.yelp.com/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ']

# %%
# WORK IN PROGRESS
for userlink in link_user:
    html_user = requests.get(userlink)
    soup_user = BeautifulSoup(html_user.content, 'lxml')
    soup_user
# Out:
# <!DOCTYPE HTML>
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]--><!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]--><!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]--><!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script nonce="353ee337">
#             (function() {
#                 var main = null;
#
#                 var main=function(){window.onerror=function(k,a,c,i,f){var j=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true"||navigator.userAgent==="selenium");var h=f&&(f.name==="ServerSideRenderingError"||f.name==="CSRFallbackError");if(j&&!h){document.body.innerHTML="<h1>Javascript Error Detected</h1>";var g=document.createElement("div");g.setAttribute("id","pastebinTraceback");var d=document.createElement("code");var e={message:k,source:a,lineno:c,colno:i,error:f};var b=document.createTextNode("JS ERROR DETECTED\n"+window.JSON.stringify(e,null,2));
# d.appendChild(b);g.appendChild(d);document.getElementsByTagName("body")[0].appendChild(g)}}};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <link href="https://s3-media0.fl.yelpcdn.com" rel="dns-prefetch"/>
# <link href="https://www.google.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://www.facebook.com" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net" rel="dns-prefetch"/>
# <link href="https://maps.googleapis.com" rel="dns-prefetch"/>
# <link href="https://js.adsrvr.org" rel="dns-prefetch"/>
# <link href="https://stats.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://idsync.rlcdn.com" rel="dns-prefetch"/>
# <script>            window.yPageStart = new Date().getTime();
# </script>
# <script>            var initialVisibilityState = document.webkitVisibilityState;
#
#                 yPerfTimings = [];
#
#                 ySitRepParams = {"uniqueRequestID": "353ee337de5bbe8f", "zipkinTraceID": "adbb2de1147c3671", "cfRayID": null, "yuv_record": "W4IdzOLD6ax1q39ZksAjC8E3V5PwODT7u03k4Wau8uItLNLgeO0rnpiVg3iCNy1EW3P-0gwfobILQBLcGXP5KAUTFEFHKGXb", "serverStartTime": 1622287877720, "datacenter": "us-east-1", "site": "main", "isLoggedIn": false, "action": null, "servlet": "user_details", "clientIP": "134.19.185.13", "is_internal_ip": false, "edgeStartTime": 1622287877654125, "b3Sampled": "0", "edgestageSubdomain": "_disabled", "disableBeacon": false};
#                 window.ySitRepParams['initialVisibilityState'] = initialVisibilityState;
#                 window.ySitRepParams['seoCohorts'] = null;
#
#
#             (function(H){H.className=H.className.replace(/\bno-js\b/,'js');})(document.documentElement);
# </script>
# <script>            pageSpeedCustomTimestamps = {};
# </script>
# <script>            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 !function(t){function e(n){if(i[n])return i[n].exports;var r=i[n]={i:n,l:!1,exports:{}};return t[n].call(r.exports,r,r.exports,e),r.l=!0,r.exports}var i={};e.m=t,e.c=i,e.d=function(t,i,n){e.o(t,i)||Object.defineProperty(t,i,{configurable:!1,enumerable:!0,get:n})},e.n=function(t){var i=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(i,"a",i),i},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=9)}([function(t,e,i){"use strict";i.d(e,"c",function(){return r}),i.d(e,"b",function(){return s}),i.d(e,"a",function(){return o});var n=i(5),r="global",s="biz",o="biz_gtag",a=[r,"m","www",s,"webview","api","admin","error_pages",o],c=function(t,e){if(Object(n.a)(a,e)>=0)return[e,t].join(".");throw new Error("google analytics attempted to set "+t+" to an unrecognized tracker alias: "+e)};e.d=c},function(t,e,i){"use strict";function n(t){for(var e=1;e<arguments.length;e++){var i=null!=arguments[e]?arguments[e]:{},n=Object.keys(i);"function"==typeof Object.getOwnPropertySymbols&&(n=n.concat(Object.getOwnPropertySymbols(i).filter(function(t){return Object.getOwnPropertyDescriptor(i,t).enumerable}))),n.forEach(function(e){r(t,e,i[e])})}return t}function r(t,e,i){return e in t?Object.defineProperty(t,e,{value:i,enumerable:!0,configurable:!0,writable:!0}):t[e]=i,t}var s=i(2),o=i.n(s),a=i(3),c=i(4),u=i(0),f=i(6);Object.keys||o.a.shim(),Object.entries||(Object.entries=function(t){for(var e=Object.keys(t),i=new Array(e.length),n=0;n<e.length;n+=1)i[n]=[e[n],t[e[n]]];return i});var l=function(){function t(t){r(this,"clientID",void 0),r(this,"dimensions",void 0),r(this,"domain",void 0),r(this,"friendlyMap",void 0),r(this,"jsDimensions",void 0),r(this,"metrics",void 0),r(this,"temporaryDimensions",void 0),r(this,"temporaryMetrics",void 0),r(this,"trackers",void 0),r(this,"userID",void 0),r(this,"enableHighVolumeEvents",void 0),window.ga||(window.ga=function(){}),window.gtag||(window.gtag=function(){}),this.reload(t)}var e=t.prototype;return e.setupTrackers=function(){var t=this;this.friendlyMap={},this.temporaryDimensions={},this.temporaryMetrics={},Object.entries(this.trackers).forEach(function(e){var i=e[0],n=e[1];t.setupTracker(String(i),String(n))})},e.setupTracker=function(t,e){var i=this,r=n({cookieDomain:this.domain,name:t,clientId:this.clientID},this.userID?{userId:this.userID}:{});window.ga("create",e,r),this.friendlyMap[t]={},this.temporaryDimensions[t]={},this.temporaryMetrics[t]={},this.addDimensionsToFriendlyMap(t,this.dimensions),this.addDimensionsToFriendlyMap(t,this.jsDimensions),this.dimensions[t]&&Object.keys(this.dimensions[t]).forEach(function(e){i.setDimension(String(e),i.dimensions[t][e][1])}),this.metrics[t]&&Object.keys(this.metrics[t]).forEach(function(e){i.setMetric(i.metrics[t][e][0],i.metrics[t][e][1],t)}),window.ga(Object(u.d)("set",t),"anonymizeIp",!0)},e.addDimensionsToFriendlyMap=function(t,e){var i=this;e&&e[t]&&Object.keys(e[t]).forEach(function(n){i.friendlyMap[t][n]=e[t][n][0]})},e.firePageviews=function(t){var e=this;Object.keys(this.trackers).forEach(function(i){e.firePageview(String(i),t)})},e.firePageviewsWithGlobalTrackerSampled=function(t){var e=this;Object.keys(this.trackers).forEach(function(i){(i!==u.c||e.enableHighVolumeEvents)&&e.firePageview(String(i),t)})},e.firePageview=function(t,e){if(t===u.a){var i=this.trackers[t],r=n({},this.dimensions[t],this.jsDimensions[t]),s=Object.keys(r).map(function(t){return r[t]}).reduce(function(t,e){var i,r=e[0],s=e[1];return n({},t,(i={},i["dimension"+r]=null===s?s:s.toString(),i))},{}),o=this.metrics[t]||{},a=Object.keys(o).map(function(t){return o[t]}).reduce(function(t,e){var i,r=e[0],s=e[1];return n({},t,(i={},i["metric"+r]=s,i))},{});window.gtag("event","page_view",n({send_to:i,anonymize_ip:!0,cookie_domain:this.domain,client_id:this.clientID},s,a,this.userID?{user_id:this.userID}:{},e?{page_path:e}:{}))}else e&&window.ga(Object(u.d)("set",t),"page",e),window.ga(Object(u.d)("send",t),"pagev ...
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main({"clientID": "07B72D921A8F40E5", "dimensions": {"global": {"account_level": [1, "anon"], "content_country": [11, "US"], "distil": [12, null], "distil_js_enabled": [13, null], "full_url": [15, "/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ"], "integration": [17, ""], "internal_ip": [18, "False"], "known_bot": [36, "other"], "referrer": [28, "none"]}, "www": {"account_level": [1, "anon"], "content_country": [15, "US"], "decrypted_yuv_id": [3, "07B72D921A8F40E5"], "distil": [53, null], "distil_js_enabled": [138, null], "full_url": [34, "/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ"], "integration": [14, ""], "internal_ip": [27, "False"], "is_biz_user": [129, "False"], "known_bot": [186, "other"], "referrer": [64, "none"], "remote_ip": [4, "134.19.185.0"], "service": [107, "yelp-main"], "viewing_self": [89, "False"], "viewport_tracking": [29, null], "user_has_notifs": [175, "False"], "ad.web_carousel_bottom_of_biz": [78, "status_quo"], "www_education_banner": [190, "disabled"], "contributions.www.remove_review_draft_modules": [183, "status_quo"], "contributions.www.war_attach_photos": [99, "enabled"], "contributions.www.war_compose_recent_photos": [102, "enabled"], "contributions.www.war_compose_redesign": [6, "enabled"], "contributions.www.war_compose_signup": [148, "disabled"], "eat24_free_delivery_banner": [45, "disabled"], "lsmoney.www.yg_raq_cards_on_search": [152, "status_quo"], "lower_promoted_delivery_threshold": [58, "reduced_to_fifteen"], "lsat.www.dropdown_header": [54, "enabled"], "lsm.www.unpakt_cta_change": [108, "unpakt_cta_enabled"], "messaging.www.composer_notifications_spam_and_hover_state": [177, "notifications_enabled"], "messaging.www.raq_cards_on_search": [61, "status_quo"], "messaging.www.yelp_guaranteed": [160, "status_quo"], "nowait_restaurant.www.no_wait_message": [106, "show_wait_or_get_in_line_copy"], "pagelet_mode_www_biz_details": [24, "allow_async"], "payment.ux.www": [197, "enabled"], "platform_pickup_filter": [20, "enabled"], "readerx.web.biz_for_services": [116, "biz_status_quo"], "readerx.web.popular_dishes": [198, "highlights_popular_dishes"], "review_actions_dropdown": [2, "disabled"], "searchux.www.services_serp_card_new_layout_v0_0": [151, "status_quo"], "styleguide_buttons": [13, "status_quo"], "styleguide_typography": [159, "status_quo"], "txn.www.checkout_page_changes": [135, "enabled"], "www_biz_details_raq_sticky": [84, "enabled"], "www_current_location_suggestion": [185, "enabled"], "www_second_page_pitch": [111, "status_quo"], "www_signup_redesign": [92, "status_quo"], "ytp_delivery_landing": [125, "platform_pages"], "ytp_eat24_yelp_style_to_iframe": [136, "status_quo"], "ytp_order_confirmation_page": [143, "enabled"], "www_search_snippets_in_sync_with_ads": [112, "status_quo_8"], "yr_diner.www.direct_checkout_for_exact_match": [163, "disabled"]}}, "domain": "yelp.com", "enable_high_volume_events": false, "ga_enabled": true, "js_dimensions": {"global": {}, "www": {"js_vertical_search_type": [39, null], "platform_order_type": [127, null]}}, "metrics": {"global": {}, "www": {"nav_unread_message_count": [5, -1]}}, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "user_id": null},null);
#             })();
#     </script>
# <script async="" charset="UTF-8" data-document-language="true" data-domain-script="5fbcd417-fbc1-4fcc-abad-f622f1bba72d" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script>
#             window.yelp = window.yelp || {};
#             window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#         </script>
# <script>        (function (d, w) {
#             if (('ontouchstart' in w) || w.DocumentTouch && d instanceof w.DocumentTouch){
#                 var html = d.getElementsByTagName("html")[0];
#                 html.classList.add("touch");
#             }
#         }(document, window));
# </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="Samira S.'s reviews, photos and other recent activity on Yelp - a fun and easy way to find, recommend and talk about what's great (and not so great) in your location." name="description"/>
# <meta content="Yelp,recommendation,San Francisco, bay area, local,business,review,friend,restaurant,dentist,doctor,salon,spa,shopping,store,share,community,massage,sushi,pizza,nails,New York,Los Angeles" name="keywords"/>
# <meta content="width=1020" name="viewport"/>
# <meta content="Yelp" name="application-name"/>
# <meta content="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b8f6d9d556d5/ico/win8-tile.png" name="msapplication-TileImage"/>
# <meta content="#c41200" name="msapplication-TileColor"/>
# <meta content="https://www.yelp.com/" name="msapplication-starturl"/>
# <meta content="#c41200" name="msapplication-navbutton-color"/>
# <meta content="width=1024;height=768" name="msapplication-window"/>
# <meta content="Go to Yelp.com" name="msapplication-tooltip"/>
# <meta content="name=Find Reviews; action-uri=/; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <meta content="name=Hot New Businesses; action-uri=/openings; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <meta content="name=Yelp Deals; action-uri=/search?find_desc=deals; icon-uri=https://s3-media0.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico" name="msapplication-task"/>
# <meta content="app-id=284910350, app-argument=yelp:///user/profile/M8eIIxg4zVGeaRFcHNrFCQ?utm_campaign=default&amp;utm_source=www" name="apple-itunes-app"/>
# <link content="#c41200" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/4374c8fd03d1/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/118ff475a341/assets/img/logos/favicon.ico" rel="shortcut icon"/>
# <link href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/>
# <link href="https://www.yelp.com/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ" rel="canonical"/>
# <meta name="critical_css_middleware"/>
# <meta content="97534753161" property="fb:app_id"/>
# <meta content="https://s3-media0.fl.yelpcdn.com/photo/qHRuq3b-mgZZzcTnHDFtyg/o.jpg" property="og:image"/>
# <meta content="Yelp" property="og:site_name"/>
# <meta content="Samira S.'s Profile" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.yelp.com/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ" property="og:url"/>
# <title>Samira S.'s Reviews | Williamsville - Yelp</title>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-Regular.yji-1d0e82fb8ca5092d63b501cb78a3fcc5.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-SemiBold.yji-64284230686011de275c4b1bb4039f54.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/OpenSans-Bold.yji-49e6b3bb7a2df2996d09b9cdd89cf166.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://s3-media0.fl.yelpcdn.com/assets/public/Poppins-Black.yji-5da432f73e49ed35ecf6e652010d4ee0.woff2" rel="preload" type="font/woff2"/>
# <script>
#     window.yelp = window.yelp || {};
#     window.yelp.critical_css_onload = function (id) {
#         this.removeAttribute("onload");
#         var el = document.querySelector('style[data-critical-css="' + id + '"]');
#         el.parentNode.removeChild(el);
#         this.rel = "stylesheet";
#     };
# </script>
# <meta id="emotion-container"/><style data-emotion-css="5r1d0t 1mpk29p 1g3e5b2 ardur y1jj6m 12anxc3 19sk4h4 8yg8ez 7vz7be n6i4z7">.css-5r1d0t{font-family:'Open Sans','Helvetica Neue',Helvetica,Arial,sans-serif;-webkit-text-decoration:none;text-decoration:none;color:rgba(0,131,143,1);font-size:14px;line-height:20px;}.css-5r1d0t:hover{-webkit-text-decoration:underline;text-decoration:underline;}.css-1mpk29p{width:24px;height:24px;display:inline-block;vertical-align:middle;position:relative;overflow:hidden;top:-0.1em;fill:rgba(43,39,60,1);}.css-1mpk29p::before{position:absolute;display:block;left:0;}.css-1mpk29p::after{content:'';display:block;position:absolute;left:0;right:0;top:0;bottom:0;}.css-1mpk29p svg{position:absolute;width:100%;height:100%;fill:inherit;display:block;left:0;top:0;right:0;bottom:0;}.css-1g3e5b2{-webkit-text-decoration:none;text-decoration:none;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-appearance:none;-moz-appearance:none;appearance:none;background-image:none;background-repeat:no-repeat;border:0;border-radius:4px;box-shadow:none;box-sizing:border-box;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;cursor:pointer;height:40px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0;padding-bottom:8px;padding-left:16px;padding-right:16px;padding-top:8px;position:relative;text-align:center;-webkit-transition:all 0.8s;transition:all 0.8s;-webkit-transition-property:background-image,background-color,background-position,background-size,border-color,box-shadow,opacity;transition-property:background-image,background-color,background-position,background-size,border-color,box-shadow,opacity;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;width:auto;background-color:transparent;border:1px solid rgba(187,186,192,1);color:rgba(43,39,60,1);background-position:calc(var(--mousedown-x) - calc(var(--button-width,100px) * 200) / 2) calc(var(--mousedown-y) - calc(var(--button-width,100px) * 200) / 2);background-size:calc(var(--button-width,100px) * 200) calc(var(--button-width,100px) * 200);}.css-1g3e5b2:active,.css-1g3e5b2:focus,.css-1g3e5b2:hover,.css-1g3e5b2:visited{-webkit-text-decoration:none;text-decoration:none;}.css-1g3e5b2:disabled{background-color:rgba(238,238,239,1);background-image:none;border-color:rgba(238,238,239,1);box-shadow:none;color:rgba(187,186,192,1);outline:none;pointer-events:none;-webkit-transition:none;transition:none;}.css-1g3e5b2:hover{box-shadow:0 1px 4px 0 rgba(0,0,0,0.3);}.css-1g3e5b2:focus{box-shadow:0 0 4px 1px rgba(0,0,0,0.35);outline:none;}@media only screen and (max-width:599px){.responsive .css-1g3e5b2{box-shadow:none;font-weight:normal;}}@media only screen and (max-width:780px){.responsive-biz .css-1g3e5b2{box-shadow:none;font-weight:normal;}}@media (pointer:coarse){.css-1g3e5b2:hover{box-shadow:none;}}.css-1g3e5b2 + a{display:inline-block;margin-left:12px;vertical-align:middle;}.css-1g3e5b2 + a:not(.css-1g3e5b2),.css-1g3e5b2 + .button-sibling:not(.css-1g3e5b2){font-size:14px;line-height:1.28571em;margin-bottom:7px;margin-top:9px;}@media only screen and (max-width:599px){.responsive .css-1g3e5b2 + a:not(.css-1g3e5b2),.responsive .css-1g3e5b2 + .button-sibling:not(.css-1g3e5b2){font-size:16px;line-height:1.31250em;}}.ie .css-1g3e5b2 > span{display:block;position:relative;}.css-1g3e5b2:active{color:rgba(43,39,60,1);}.css-1g3e5b2:disabled{background-color:transparent;border:1px solid rgba(207,206,213,1);}.css-1g3e5b2:focus{background-color:rgba(0,0,0,0.12);}.css-1g3e5b2:hover{background-color:rgba(0,0,0,0.12);color:rgba(43,39,60,1);box-shadow:none;}.css-1g3e5b2[data-activated='true']{background-color:rgba(0,0,0,0.12);background-image:radial-gradient(rgba(0,0,0,0.05) 1%,transparent 1%);}.css-1g3e5b2[data-activated='true']:active{-webkit-transition:all 0s;transition:all 0s;back ...
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-89529094a472499f5359.chunk.css" media="all" rel="stylesheet" type="text/css"/><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp_main.yji-8553a797f80748b46749.chunk.css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if (IE 9)|(lt IE 9) ]> <link rel="stylesheet" type="text/css" media="all" href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/0547c86a37db/www-pkg-main.css">
#             <link rel="stylesheet" type="text/css" media="all" href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/4df7a42c19fb/www-pkg-more.css"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <link href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/4277ac50b3f0/www-pkg.css" media="all" rel="stylesheet" type="text/css"/> <!--<![endif]-->
# <link href="https://s3-media0.fl.yelpcdn.com/assets/2/www/css/6a9b91419ed3/user_details-pkg.css" media="all" rel="stylesheet" type="text/css"/>
# <title data-rh="true"></title>
# <script>/*! loadCSS. [c]2017 Filament Group, Inc. MIT License */
# (function(a){if(!a.loadCSS){a.loadCSS=function(){}}var b=loadCSS.relpreload={};b.support=(function(){var d;try{d=a.document.createElement("link").relList.supports("preload")}catch(f){d=false}return function(){return d}})();b.bindMediaToggle=function(e){var f=e.media||"all";function d(){e.media=f}if(e.addEventListener){e.addEventListener("load",d)}else{if(e.attachEvent){e.attachEvent("onload",d)}}setTimeout(function(){e.rel="stylesheet";e.media="only x"
# });setTimeout(d,3000)};b.poly=function(){if(b.support()){return}var d=a.document.getElementsByTagName("link");for(var e=0;e<d.length;e++){var f=d[e];if(f.rel==="preload"&&f.getAttribute("as")==="style"&&!f.getAttribute("data-loadcss")){f.setAttribute("data-loadcss",true);b.bindMediaToggle(f)}}};if(!b.support()){b.poly();var c=a.setInterval(b.poly,500);if(a.addEventListener){a.addEventListener("load",function(){b.poly();a.clearInterval(c)})}else{if(a.attachEvent){a.attachEvent("onload",function(){b.poly();
# a.clearInterval(c)})}}}if(typeof exports!=="undefined"){exports.loadCSS=loadCSS}else{a.loadCSS=loadCSS}}(typeof global!=="undefined"?global:this));</script>
# <script></script>
# <link href="https://www.facebook.com/yelp" id="sitelink-profile-facebook" itemprop="sameAs"/>
# <link href="https://twitter.com/yelp" id="sitelink-profile-twitter" itemprop="sameAs"/>
# <link href="https://www.linkedin.com/company/31517" id="sitelink-profile-linkedin" itemprop="sameAs"/>
# <link href="https://instagram.com/yelp" id="sitelink-profile-instagram" itemprop="sameAs"/>
# <meta itemref="sitename sitelink  sitelink-profile-facebook sitelink-profile-twitter sitelink-profile-linkedin sitelink-profile-instagram" itemscope="" itemtype="http://schema.org/WebSite"/>
# <meta content="Yelp" id="sitename" itemprop="name"/>
# <link href="https://www.yelp.com/" id="sitelink" itemprop="url"/>
# <script>            document.cookie = "xcj=1|yS1gKxsh1bDgL3s8ngrVFWoMPo4I8ADpzpbaeP2jteg; Domain=.yelp.com; expires=Fri, 27 Aug 2021 11:31:18 GMT; Max-Age=7776000; Path=/";
# </script>
# </head>
# <body class="jquery country-us logged-out" id="yelp_main_body">
# <script>(function (d, w) {
#     var supportsSVG = (
#         !!d.createElementNS &&
#         !!d.createElementNS(
#             'http://www.w3.org/2000/svg',
#             'svg'
#         ).createSVGRect
#     );
#     var cdnPath = 'https://s3-media0.fl.yelpcdn.com/assets/srv0/svg_icons/db39ff735323/assets/svg_sprite.js';
#     var head = d.getElementsByTagName('head')[0];
#     function fallback() {
#         var link = d.createElement('link');
#         link.rel = 'stylesheet';
#         link.href = 'https://s3-media0.fl.yelpcdn.com/assets/srv0/svg_icons/aaf9c39cde51/assets/sprite.css';
#         head.appendChild(link);
#     }
#     if (!supportsSVG) {
#         fallback();
#         return;
#     }
#     if (!w.yelp) {
#         w.yelp = {};
#     }
#     w.yelp.__injectSvgSpritesheet = function (svg) {
#         document.body.insertAdjacentHTML('afterbegin', svg);
#         delete window.yelp.__injectSvgSpritesheet;
#     }
#     function onError() {
#         d.documentElement.className = [
#             d.documentElement.className,
#             'icon-svg-unavailable'
#         ].join(' ');
#         fallback();
#         return true;
#     }
#     var script = d.createElement('script');
#     script.async = true;
#     script.onerror = onError;
#     script.src = cdnPath + '?callback=window.yelp.__injectSvgSpritesheet';
#     head.appendChild(script);
# }(document, window));</script>
# <noscript>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/svg_icons/aaf9c39cde51/assets/sprite.css" rel="stylesheet"/>
# </noscript>
# <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "61ba06c815ef134d66c4ea4d43a5a235a05aed31", "metaData": {"projectName": "yelp_main"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1.0}, "apiKey": "ac0c27867d3912ce5714ff131041af4f", "enabled": true}</script>
# <script>            window.pageSpeedCustomTimestamps['body:start'] = (new Date()).getTime();
# </script>
# <div id="fb-root"></div>
# <div class="lang-en" id="wrap">
# <div class="page-header">
# <yelp-react-root><div data-hypernova-id="506aee7d-1d77-4194-9d16-1d98113920d2" data-hypernova-key="yelp_main__61ba06c815ef134d66c4ea4d43a5a235a05aed31__yelp_main__ConsumerHeader__dynamic"><div class="border-color--default__373c0__2oFDT"><div class="consumer-header-container__373c0__lbNbB border--bottom__373c0__uPbXS border-color--default__373c0__2oFDT background-color--white__373c0__GVEnp"><div class="consumer-header__373c0__Qzfd9 border-color--default__373c0__2oFDT"><div class="arrange__373c0__UHqhV vertical-align-middle__373c0__2TQsQ border-color--default__373c0__2oFDT"><div class="logo-arrange-unit__373c0__2SvbP arrange-unit__373c0__1piwO border-color--default__373c0__2oFDT"><div class="margin-r4__373c0__398s1 margin-sm-r0__373c0__3Oak_ border-color--default__373c0__2oFDT"><div class="logo__373c0__3xbyt logo-image__373c0__2MtBx logo-container__373c0__2d_nu border-color--default__373c0__2oFDT" data-analytics-label="logo" id="logo"><a class="logo-link__373c0__1l5qC css-5r1d0t" href="/" name="" rel="" role="link" target="">Yelp</a></div></div></div><div class="search-suggest-arrange-unit__373c0__1r2IG arrange-unit__373c0__1piwO arrange-unit-fill__373c0__17z0h border-color--default__373c0__2oFDT"><div class="search-suggest-container-outer__373c0__9lfvS border-color--default__373c0__2oFDT"><div class="search-suggest-container-inner__373c0__2pXbM border-color--default__373c0__2oFDT"><div class="arrange__373c0__UHqhV gutter-2__373c0__3Zpeq border-color--default__373c0__2oFDT"><div class="arrange-unit__373c0__1piwO arrange-unit-fill__373c0__17z0h border-color--default__373c0__2oFDT"><div class="search-suggest__373c0__31JJZ"><div class=""><form action="/search" class="find-near-form__373c0__QkXpc" id="header_find_form" method="get" role="search"><div class="undefined arrange__373c0__UHqhV border-color--default__373c0__2oFDT"><div class="arrange-unit__373c0__1piwO arrange-unit-fill__373c0__17z0h border-color--default__373c0__2oFDT"><div class="find-near-arrange__373c0__dhora arrange__373c0__UHqhV layout-equal__373c0__2jcUj border-color--default__373c0__2oFDT"><div class="find-near-arrange-unit__373c0__1x8M9 arrange-unit__373c0__1piwO border-color--default__373c0__2oFDT"><label class="label__373c0__2kYNn pseudo-input__373c0__5zGeH pseudo-input__373c0__3aR8D pseudo-input--find-near__373c0__2MkBe pseudo-input--find__373c0__tF4yY" for="search_description"><span class="pseudo-input-text__373c0__1Waqo display--inline__373c0__1DbOG border-color--default__373c0__2oFDT"><div class="pseudo-input-icon-container__373c0__2jsaM margin-r1-5__373c0__1Vie3 border-color--default__373c0__2oFDT"><span aria-hidden="false" aria-label="Find" class="icon--24-search-v2 pseudo-input-icon__373c0__1e_Dt css-1mpk29p"><svg class="icon_svg" height="24" width="24"><path d="M21.853 20.355l-3.444-3.443a9.428 9.428 0 10-16.761-6.171 9.428 9.428 0 0015.348 7.586l3.443 3.442a1 1 0 101.414-1.414zM5.82 16.245a7.429 7.429 0 115.253 2.175 7.38 7.38 0 01-5.253-2.176z"></path></svg></span></div></span><div class="border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"><div class="typeahead__373c0__HGjy7 border-color--default__373c0__2oFDT"><input aria-hidden="true" autocomplete="off" class="input__373c0__1kQwh input__373c0__3GvbQ hidden-input__373c0__3qUuQ" disabled="" placeholder=" " spellcheck="false" tabindex="-1" type="text" value=""/><input aria-autocomplete="list" autocomplete="off" class="input__373c0__1kQwh input__373c0__3GvbQ original-input__373c0__3YWBR" data-testid="suggest-desc-input" id="search_description" name="find_desc" placeholder="tacos, cheap dinner, Max’s" tabindex="0" type="text" value=""/></div></div></label></div><div class="responsive-gutter__373c0__1mEC1 location-arrange-unit__373c0__O8Ilj find-near-arrange-unit__373c0__1x8M9 arrange-unit__373c0__1piwO layout-stack-gutter-1-5__373c0__3a0i4 margin-sm-t1-5__373c0__1bZ_H border-color--default__373c0__2oFDT"><label class="label__373c0__2kYNn pseudo-input__373c0__5zGeH pseudo-input__373c0__3aR ...
# <script data-hypernova-id="506aee7d-1d77-4194-9d16-1d98113920d2" data-hypernova-key="yelp_main__61ba06c815ef134d66c4ea4d43a5a235a05aed31__yelp_main__ConsumerHeader__dynamic" type="application/json"><!--{"holidayModifier":null,"locale":"en_US","uniqueRequestId":"353ee337de5bbe8f","messages":{" and ":" and "," and let us know if you think the content you’ve reported may violate these guidelines.":" and let us know if you think the content you’ve reported may violate these guidelines.","%{businessName} accepts %{paymentAttributesToDisplay}.":"%{businessName} accepts %{paymentAttributesToDisplay}.","%{businessName} also recommends":"%{businessName} also recommends","%{businessName} has %{businessRating} stars.":"%{businessName} has %{businessRating} stars.","%{businessName} is a Yelp advertiser.":"%{businessName} is a Yelp advertiser.","%{businessName} is open %{daysOpenToDisplay}.":"%{businessName} is open %{daysOpenToDisplay}.","%{businessOwnerRole} of %{businessName}":"%{businessOwnerRole} of %{businessName}","%{confirmedDay} at %{confirmedTime}":"%{confirmedDay} at %{confirmedTime}","%{coverCount} person||||%{coverCount} people":"%{coverCount} person||||%{coverCount} people","%{currentNumberLicense} of %{totalNumberLicense}":"%{currentNumberLicense} of %{totalNumberLicense}","%{current_page} of %{total_pages}":"%{current_page} of %{total_pages}","%{minWait} - %{maxWait} mins":"%{minWait} - %{maxWait} mins","%{number} of %{total}":"%{number} of %{total}","%{price}/hr":"%{price}/hr","%{rating} star rating":"%{rating} star rating","%{smart_count} More Attribute||||%{smart_count} More Attributes":"%{smart_count} More Attribute||||%{smart_count} More Attributes","%{smart_count} Photo||||%{smart_count} Photos":"%{smart_count} Photo||||%{smart_count} Photos","%{smart_count} Place||||%{smart_count} Places":"%{smart_count} Place||||%{smart_count} Places","%{smart_count} Review||||%{smart_count} Reviews":"%{smart_count} Review||||%{smart_count} Reviews","%{smart_count} Update||||%{smart_count} Updates":"%{smart_count} Update||||%{smart_count} Updates","%{smart_count} other review that is not currently recommended||||%{smart_count} other reviews that are not currently recommended":"%{smart_count} other review that is not currently recommended||||%{smart_count} other reviews that are not currently recommended","%{smart_count} person found this helpful||||%{smart_count} people found this helpful":"%{smart_count} person found this helpful||||%{smart_count} people found this helpful","%{smart_count} recommended review||||%{smart_count} recommended reviews":"%{smart_count} recommended review||||%{smart_count} recommended reviews","%{smart_count} review mentioning “%{query}”||||%{smart_count} reviews mentioning “%{query}”":"%{smart_count} review mentioning “%{query}”||||%{smart_count} reviews mentioning “%{query}”","%{smart_count} review that is not currently recommended||||%{smart_count} reviews that are not currently recommended":"%{smart_count} review that is not currently recommended||||%{smart_count} reviews that are not currently recommended","%{smart_count} review||||%{smart_count} reviews":"%{smart_count} review||||%{smart_count} reviews","%{smart_count} violation: %{description}||||%{smart_count} violations: %{description}":"%{smart_count} violation: %{description}||||%{smart_count} violations: %{description}","%{username} said":"%{username} said","%{waitlistClosedTimeText}":"%{waitlistClosedTimeText}","(111) 111-1111":"(111) 111-1111","(Optional)":"(Optional)","(Optional) Any more details you'd like to share ?":"(Optional) Any more details you'd like to share ?","(no rating)":"(no rating)","*":"*","+%{smart_count} Popular Dish||||+%{smart_count} Popular Dishes":"+%{smart_count} Popular Dish||||+%{smart_count} Popular Dishes",", ":", ","0 mins":"0 mins","1 hour":"1 hour","1 truck":"1 truck","2 hours":"2 hours","2 movers":"2 movers","3 hours":"3 hours","4 or more":"4 or more","4 or more hours":"4 or more hours","<0&gt;<1&gt;<2/&gt;</1& ...
# <script nonce="353ee337">
#             (function() {
#                 var main = null;
#
#                 var main=(function(){function a(b){window.yDFP.ABP={};window.yDFP.ABP.getPixelSource=function(c){return b+"?ch="+c+"&rn="+Math.random()*11};window.yDFP.ABP.detect=function(l){var g=false;var f=2;var i=false;var h=false;function k(n,m){if(f===0||m>400){n(f===0&&g)}else{setTimeout(function(){k(n,m*2)},m*2)}}function j(){if(f!==0){return}g=!i&&h}var e=function(){f-=1;j()};var d=new Image();d.onload=e;d.onerror=function(){i=true;e()};d.src=window.yDFP.ABP.getPixelSource(1);var c=new Image();c.onload=e;
# c.onerror=function(){h=true;e()};c.src=window.yDFP.ABP.getPixelSource(2);k(l,100)};window.yDFP.ABP.abpInstalledChannel="1382551876";window.yDFP.ABP.abpNotInstalledChannel="2859285073"}window.yDFP=window.yDFP||{};window.yDFP.initABPDetection=a;return window.yDFP.initABPDetection})();
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("/px.gif");
#             })();
#     </script>
# <div id="print-masthead">
# <img alt="Yelp" class="print-bkg-img" src="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/b7e9d647188d/gfx/header_print.gif"/>
# </div>
# </div>
# <span class="offscreen" id="page-content"> </span>
# <div class="main-content-wrap main-content-wrap--full">
# <div class="top-shelf top-shelf-grey elite-stars">
# <div class="content-container">
# <div id="alert-container">
# </div>
# <div class="user-profile_container">
# <div class="user-profile_avatar">
# <div class="photo-slideshow photo-slideshow--full-width photo-slideshow--rounded js-photo-slideshow-user-details">
# <div class="photo-slideshow_slide is-active" style="background-image: url(https://s3-media0.fl.yelpcdn.com/photo/qHRuq3b-mgZZzcTnHDFtyg/ls.jpg);">
# <div class="photo-slideshow_image">
# <a href="/user_photos?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <img alt="Samira S." class="photo-box-img" height="250" loading="lazy" src="https://s3-media0.fl.yelpcdn.com/photo/qHRuq3b-mgZZzcTnHDFtyg/ls.jpg" srcset="https://s3-media0.fl.yelpcdn.com/photo/qHRuq3b-mgZZzcTnHDFtyg/258s.jpg 1.03x,https://s3-media0.fl.yelpcdn.com/photo/qHRuq3b-mgZZzcTnHDFtyg/300s.jpg 1.20x,https://s3-media0.fl.yelpcdn.com/photo/qHRuq3b-mgZZzcTnHDFtyg/348s.jpg 1.39x" width="250"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="user-profile_content-wrapper arrange arrange--bottom arrange--30">
# <div aria-hidden="true" class="user-profile_avatar-dummy arrange_unit"></div>
# <div class="user-profile_info arrange_unit">
# <h1>Samira S.</h1>
# <h3 class="user-location alternate">From Williamsville, NY</h3>
# <div class="clearfix">
# <ul class="user-passport-stats">
# <li class="friend-count">
# <span aria-hidden="true" class="icon icon--24-friends icon--size-24" style="fill: #f15c00; width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_friends"></use>
# </svg>
# </span>
# <strong>180</strong> Friends
#         </li>
# <li class="review-count">
# <span aria-hidden="true" class="icon icon--24-review icon--size-24" style="fill: #f15c00; width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_review"></use>
# </svg>
# </span>
# <strong>112</strong> Reviews
#         </li>
# <li class="photo-count">
# <span aria-hidden="true" class="icon icon--24-camera icon--size-24" style="fill: #f15c00; width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_camera"></use>
# </svg>
# </span>
# <strong>209</strong> Photos
#         </li>
# </ul>
# </div>
# <div class="clearfix u-space-b1">
# <a class="badge-bar u-space-r1" href="/elite">
# <span class="elite-badge">Elite 2021</span>
# <span class="elite-badge">’20</span>
# <span class="elite-badge">’19</span>
# </a>
# <a class="u-nowrap u-align-middle" href="/elite">
# <small>What is Yelp Elite?</small>
# </a>
# </div>
# </div>
# <div class="user-profile_actions arrange_unit">
# <ul class="action-link-list">
# <li>
# <a class="arrange arrange--middle add-friend" href="/user_add_friend?return_url=/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ&amp;userid=M8eIIxg4zVGeaRFcHNrFCQ" rel="">
# <div class="action-link_icon arrange_unit">
# <span aria-hidden="true" class="icon icon--18-add-friend icon--size-18 icon--currentColor" style="width: 18px; height: 18px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#18x18_add_friend"></use>
# </svg>
# </span>
# </div>
# <div class="action-link_label arrange_unit arrange_unit--fill">
#             Add friend
#         </div>
# </a>
# </li>
# <li>
# <a class="arrange arrange--middle send-compliment" href="/thanx?previous_url=/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ&amp;user_id=M8eIIxg4zVGeaRFcHNrFCQ" rel="">
# <div class="action-link_icon arrange_unit">
# <span aria-hidden="true" class="icon icon--18-compliment icon--size-18 icon--currentColor" style="width: 18px; height: 18px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#18x18_compliment"></use>
# </svg>
# </span>
# </div>
# <div class="action-link_label arrange_unit arrange_unit--fill">
#             Compliment
#         </div>
# </a>
# </li>
# <li>
# <a class="arrange arrange--middle send-pm" href="/mail?action_send_form=1&amp;dst=M8eIIxg4zVGeaRFcHNrFCQ&amp;return_url=/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ" rel="Samira S.">
# <div class="action-link_icon arrange_unit">
# <span aria-hidden="true" class="icon icon--18-speech icon--size-18 icon--currentColor" style="width: 18px; height: 18px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#18x18_speech"></use>
# </svg>
# </span>
# </div>
# <div class="action-link_label arrange_unit arrange_unit--fill">
#             Send message
#         </div>
# </a>
# </li>
# <li>
# <a class="arrange arrange--middle manage-following manage-following-add" data-csrf-token="3d909fac98fc19a03ef9c099185da9eae6e453ddc0ba9d6a1a4ffe966b0840ac" href="/following_user/add?dst_user_id=M8eIIxg4zVGeaRFcHNrFCQ&amp;previous_url=/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ" rel="M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="action-link_icon arrange_unit">
# <span aria-hidden="true" class="icon icon--18-following icon--size-18 icon--currentColor" style="width: 18px; height: 18px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#18x18_following"></use>
# </svg>
# </span>
# </div>
# <div class="action-link_label arrange_unit arrange_unit--fill">
#             Follow Samira S.
#         </div>
# </a>
# </li>
# <li>
# <a class="arrange arrange--middle manage-following manage-following-remove hidden" data-csrf-token="3d909fac98fc19a03ef9c099185da9eae6e453ddc0ba9d6a1a4ffe966b0840ac" href="/following_user/remove?dst_user_id=M8eIIxg4zVGeaRFcHNrFCQ&amp;previous_url=/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ" rel="M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="action-link_icon arrange_unit">
# <span aria-hidden="true" class="icon icon--18-unfollow icon--size-18 icon--currentColor" style="width: 18px; height: 18px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#18x18_unfollow"></use>
# </svg>
# </span>
# </div>
# <div class="action-link_label arrange_unit arrange_unit--fill">
#             Stop following Samira S.
#         </div>
# </a>
# </li>
# <li>
# <a class="arrange arrange--middle" href="/user_details_reviews_self?review_filter=shared&amp;userid=M8eIIxg4zVGeaRFcHNrFCQ" rel="">
# <div class="action-link_icon arrange_unit">
# <span aria-hidden="true" class="icon icon--18-similar icon--size-18 icon--currentColor" style="width: 18px; height: 18px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#18x18_similar"></use>
# </svg>
# </span>
# </div>
# <div class="action-link_label arrange_unit arrange_unit--fill">
#             Similar Reviews
#         </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="content-container" id="super-container">
# <div class="clearfix layout-block layout-n user-details_container">
# <div class="column column-alpha user-details_sidebar">
# <div class="ysection">
# <div class="titled-nav js-titled-nav">
# <input class="titled-nav-dropdown_handler" id="titled-nav-39f0f5de-3e22-4018-905c-2707ff8ba253" role="presentation" type="checkbox"/>
# <div class="titled-nav-dropdown hidden-non-responsive-block responsive-hidden-large">
# <label class="titled-nav-dropdown_trigger" for="titled-nav-39f0f5de-3e22-4018-905c-2707ff8ba253">
# <span class="arrange arrange--middle titled-nav-dropdown_content">
# <span class="arrange_unit arrange_unit--fill titled-nav-dropdown_shadow">
# <span class="titled-nav-dropdown_faded-title">
# <strong>Samira's Profile</strong>
#
#                         Profile Overview
#
#                     </span>
# </span>
# <span class="arrange_unit titled-nav-dropdown_icon">
# <span aria-hidden="true" class="icon icon--24-chevron-down icon--size-24 titled-nav-dropdown_expand" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_chevron_down"></use>
# </svg>
# </span>
# <span aria-hidden="true" class="icon icon--24-chevron-up icon--size-24 titled-nav-dropdown_collapse" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_chevron_up"></use>
# </svg>
# </span>
# </span>
# </span>
# </label>
# </div>
# <div class="titled-nav_menus">
# <div class="titled-nav_menu">
# <div class="titled-nav-header">
# <div class="arrange arrange--top">
# <div class="arrange_unit arrange_unit--fill">
# <div class="titled-nav-header_content">
# <h3>Samira's Profile</h3>
# </div>
# </div>
# <div class="arrange_unit">
# </div>
# </div>
# </div>
# <ul class="titled-nav_items">
# <li class="titled-nav_item">
# <a class="titled-nav_link is-active" href="/user_details?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="titled-nav_link-content arrange arrange--middle arrange--6">
# <div class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-profile icon--size-24 titled-nav_icon" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_profile"></use>
# </svg>
# </span>
# </div>
# <div class="arrange_unit arrange_unit--fill">
# <span class="titled-nav_link-label">Profile Overview</span>
# </div>
# </div>
# </a>
# </li>
# <li class="titled-nav_item">
# <a class="titled-nav_link" href="/user_details_friends?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="titled-nav_link-content arrange arrange--middle arrange--6">
# <div class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-friends icon--size-24 titled-nav_icon" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_friends"></use>
# </svg>
# </span>
# </div>
# <div class="arrange_unit arrange_unit--fill">
# <span class="titled-nav_link-label">Friends</span>
# </div>
# </div>
# </a>
# </li>
# <li class="titled-nav_item">
# <a class="titled-nav_link" href="/user_details_reviews_self?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="titled-nav_link-content arrange arrange--middle arrange--6">
# <div class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-review icon--size-24 titled-nav_icon" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_review"></use>
# </svg>
# </span>
# </div>
# <div class="arrange_unit arrange_unit--fill">
# <span class="titled-nav_link-label">Reviews</span>
# </div>
# </div>
# </a>
# </li>
# <li class="titled-nav_item">
# <a class="titled-nav_link" href="/user_local_photos?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="titled-nav_link-content arrange arrange--middle arrange--6">
# <div class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-camera icon--size-24 titled-nav_icon" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_camera"></use>
# </svg>
# </span>
# </div>
# <div class="arrange_unit arrange_unit--fill">
# <span class="titled-nav_link-label">Business Photos</span>
# </div>
# </div>
# </a>
# </li>
# <li class="titled-nav_item">
# <a class="titled-nav_link" href="/user_details_thanx?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="titled-nav_link-content arrange arrange--middle arrange--6">
# <div class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-compliment icon--size-24 titled-nav_icon" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_compliment"></use>
# </svg>
# </span>
# </div>
# <div class="arrange_unit arrange_unit--fill">
# <span class="titled-nav_link-label">Compliments</span>
# </div>
# </div>
# </a>
# </li>
# <li class="titled-nav_item">
# <a class="titled-nav_link" href="/user_details_quicktips?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="titled-nav_link-content arrange arrange--middle arrange--6">
# <div class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-light-bulb icon--size-24 titled-nav_icon" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_light_bulb"></use>
# </svg>
# </span>
# </div>
# <div class="arrange_unit arrange_unit--fill">
# <span class="titled-nav_link-label">Tips</span>
# </div>
# </div>
# </a>
# </li>
# <li class="titled-nav_item">
# <a class="titled-nav_link" href="/collections/user?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="titled-nav_link-content arrange arrange--middle arrange--6">
# <div class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-save icon--size-24 titled-nav_icon" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_save"></use>
# </svg>
# </span>
# </div>
# <div class="arrange_unit arrange_unit--fill">
# <span class="titled-nav_link-label">Collections</span>
# </div>
# </div>
# </a>
# </li>
# <li class="titled-nav_item">
# <a class="titled-nav_link" href="/user_details_following?userid=M8eIIxg4zVGeaRFcHNrFCQ">
# <div class="titled-nav_link-content arrange arrange--middle arrange--6">
# <div class="arrange_unit">
# <span aria-hidden="true" class="icon icon--24-following icon--size-24 titled-nav_icon" style="width: 24px; height: 24px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#24x24_following"></use>
# </svg>
# </span>
# </div>
# <div class="arrange_unit arrange_unit--fill">
# <span class="titled-nav_link-label">Following</span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="titled-nav-header responsive-hidden-large" role="presentation"></div>
# </div>
# </div>
# </div>
# <div class="ysection">
# <ul class="ylist">
# <li>
# <a class="report-user u-text-subtle" href="/flag_content?flag_id=M8eIIxg4zVGeaRFcHNrFCQ&amp;flag_type=user_profile&amp;previous_url=%2Fuser_details%3Fuserid%3DM8eIIxg4zVGeaRFcHNrFCQ">
# <span aria-hidden="true" class="icon icon--14-flag icon--size-14 u-space-r-half" style="width: 14px; height: 14px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#14x14_flag"></use>
# </svg>
# </span>Report this profile
#     </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="column column-beta">
# <div class="user-details-overview">
# <div class="user-details-overview_activity">
# <div class="media-details js-media-details js-media-details-template hidden">
# <div class="media-details_container media-details_container--embed media-details_container--with-sidebar">
# <div class="media-container js-media-container"></div>
# <div class="media-nav js-media-nav"></div>
# </div>
# </div>
# <div class="user-details-overview_reviews">
# <div class="user-details-overview_published-reviews">
# <div class="section-header section-header--no-spacing">
# <h2 class="section-header_title">Reviews</h2>
# <div class="clearfix">
# <div class="pull-left">
# <div class="tab-nav-container">
# <ul class="tab-nav js-tab-nav" role="tablist">
# <li class="tab-nav_item tab-nav_item--last" role="presentation">
# ...
# </li>
# <li class="footer-menu_item">
# <a href="https://officialblog.yelp.com/">Blog</a>
# </li>
# <li class="footer-menu_item">
# <a href="https://www.yelp-support.com/?l=en_US">Support</a>
# </li>
# <li class="footer-menu_item">
# <a href="/static?p=tos">Terms</a>
# </li>
# </ul>
# </div>
# <div class="main-footer_city-landscape-img" role="presentation"></div>
# <small class="main-footer_copyright">
#             Copyright © 2004–2021 Yelp Inc. Yelp, <img alt="Yelp logo" class="main-footer_logo-copyright" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/17089be275f0/assets/img/logos/logo_desktop_xsmall_outline.png" srcset="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/0aade8725c91/assets/img/logos/logo_desktop_xsmall_outline@2x.png 2x"/>, <img alt="Yelp burst" class="main-footer_logo-burst" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/58cfc999e1f5/assets/img/logos/burst_desktop_xsmall_outline.png" srcset="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_styleguide/dcb526e86d86/assets/img/logos/burst_desktop_xsmall_outline@2x.png 2x"/> and related marks are registered trademarks of Yelp.
#     </small>
# <!--Source: Freebase (https://www.freebase.com/), licensed under CC-BY (https://creativecommons.org/licenses/by/2.5/)-->
# </div>
# </div>
# </div>
# <!-- google_ad_section_end -->
# <div id="page-popups" style="display: none;">
# </div>
# </div>
# <script>            yConfig = {"isLoggedIn": false, "isLive": true, "isSitRepEnabled": true, "isWebviewRequest": false, "webviewInfo": {}, "webviewFlow": null, "enabledSitRepChannels": {"traffic_quality": true, "search_suggest_events": true}, "cookies": {"AD_CLICKS": "adc", "ADMIN_CM_SCOREBOARD_SETTINGS": "acms", "ADMIN_SEARCH_USERDATA": "ud", "APP_PITCH_CLOSED": "ap", "XCJ": "xcj", "COOKIE_INFO": "cim", "DEBUG": "debug", "DISMISSIBLE_MESSAGE_COOKIE": "dm", "EXPR_OVERRIDE": "expr", "HOMEPAGE_SERVICE_ACTIVITY_FEED": "hsfd", "LOCATION": "location", "MESSAGE_SENDER_PASSED_CAPTCHA": "mspc", "PREVIOUS_UNIQUE_REQUEST_ID": "pid", "PRIVACY_POLICY_NOTICE": "ppn", "QUANTCAST": "qntcst", "RECENT_LOCATIONS": "recentlocations", "RESERVATION_SEARCH_PARAMS": "rsp", "SIGNUP_TRACK": "strack", "UPGRADES_IN_ARREARS": "uia", "USED_LOCALE_SELECTOR": "used_locale_selector", "MO_MAP": "mmp"}, "imageUrls": {"mapMarkers": "https://s3-media0.fl.yelpcdn.com/assets/2/www/img/fca83ddb80f2/map/map_markers_sprite.png", "stars": "https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_web/9bec2045845c/assets/img/stars/stars.png"}, "comscore": {"c1": 2, "c2": 7130511, "c3": "", "c4": "", "c5": "", "c6": "", "c15": ""}, "uaInfo": {"device": {"family": "Other", "brand": null, "model": null}, "os": {"family": "Other", "major": null, "minor": null, "patch": null, "patch_minor": null}, "string": "python-requests/2.24.0", "user_agent": {"family": "Python Requests", "major": "2", "minor": "24", "patch": null}, "attributes": {}}, "isBugsnagEnabled": true, "deprecatedEncryptedYUV": "W4IdzOLD6ax1q39ZksAjC8E3V5PwODT7u03k4Wau8uItLNLgeO0rnpiVg3iCNy1EW3P-0gwfobILQBLcGXP5KAUTFEFHKGXb", "yelpcodeTemplateVersion": "61ba06c815", "vendorExternalURLs": {}, "isClientErrorsEnabled": false, "cookieDomain": ".www.yelp.com", "uniqueRequestId": "353ee337de5bbe8f", "recaptchaPublicKey": "6Le5OSYTAAAAADy8seTrWT0eqpS795iV32Gm9Ag1", "recaptchaV3PublicKey": "6Le2lKQUAAAAAMMHRuHPaDwOMSodMg2FiVTGSw2Y", "hcaptchaSitekey": "6660d4df-1884-4ac6-a933-e5f3bd460946", "googlePlacesUrl": "//maps.googleapis.com/maps/api/js?key=AIzaSyByT6TXVL4jSf0MrzRwg0eG66A8-P4r0ps\u0026language=en\u0026libraries=places"};
# </script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/2/www/js/bd55d872adec/assets/vendor_external/closure_localizations_en_US.min.js" type="text/javascript"></script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":[]}</script>
# <script>            window.yelp = window.yelp || {};
#             window.yelp.reactRenderMode = "legacy";
# </script>
# <script crossorigin="anonymous" integrity="sha384-FbHUaR69a828hqWjPw4PFllFj1bvveKOTWORGkyosCw720HXy/56+2hSuQDaogMb" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/6fef55c62df3/assets/vendor/babel-polyfill/6.23.0/polyfill.min.js"></script><script nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/3576a6e73c9d/assets/vendor/jquery/1.8.3/jquery.min.js"></script><script nonce="353ee337">if(document.readyState === 'interactive') jQuery.ready();
#         yConfig = window.yConfig || {};
#         yConfig.vendorExternalURLs = yConfig.vendorExternalURLs || {};
#         </script><script crossorigin="anonymous" integrity="sha384-qn+ML/QkkJxqn4LLs1zjaKxlTg2Bl/6yU/xBTJAgxkmNGc6kMZyeskAG0a7eJBR1" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/f808b8e8ab51/assets/vendor/react/16.8.6/umd/react.production.min.js"></script><script crossorigin="anonymous" integrity="sha384-85IMG5rvmoDsmMeWK/qUU4kwnYXVpC+o9hoHMLi4bpNR+gMEiPLrvkZCgsr7WWgV" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/fad5842bd019/assets/vendor/react-dom/16.8.6/umd/react-dom.production.min.js"></script><script crossorigin="anonymous" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp_main_webpack_runtime.yji-c60247a61dcb613c867d.js"></script><script crossorigin="anonymous" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp_js_packages.yji-3ad66336773f9d5e3d34.chunk.js"></script><script crossorigin="anonymous" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/public/common_chunk.yji-23a8233d4b3b4e75e4f7.chunk.js"></script><script crossorigin="anonymous" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_core.yji-2358b416cbd24ecdd677.chunk.js"></script><script crossorigin="anonymous" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_jquery.yji-8bd9ec45028f2e17e132.chunk.js"></script><script crossorigin="anonymous" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_misc_react.yji-084f82900bbb5eccb098.chunk.js"></script><script crossorigin="anonymous" nonce="353ee337" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_user_details.yji-cc53ae6f4b3f372be6cf.chunk.js"></script><script nonce="353ee337">
#                 yConfig.vendorExternalURLs["plugin-detect"]=['https://s3-media0.fl.yelpcdn.com/assets/2/www/js/bfd62b330c7a/assets/vendor_external/plugin-detect-0.6.3.min.js']
#
#                 yConfig.vendorExternalURLs["fast-click"]=['https://s3-media0.fl.yelpcdn.com/assets/2/www/js/960df06ce458/assets/vendor_external/fastclick.min.js']
#                 yelp.init.initDelegatedDropdowns();
# yelp.init.initDelegatedDropdowns();
# yelp.init.attachGhostHovercard("qype", "    \u003cdiv id=\"qype-ghost-user-hovercard\"\u003e\n        \u003cdiv class=\"whatsthis-hovercard\"\u003e\n            \u003ch3\u003eWhat's This?\u003c/h3\u003e\n            \u003cp\u003eThis user has arrived from Qype, a company acquired by Yelp in 2012. We have integrated the two sites to bring you one great local experience.\u003c/p\u003e\n        \u003c/div\u003e\n    \u003c/div\u003e\n");
# yelp.init.attachGhostHovercard("rk", "    \u003cdiv id=\"rk-ghost-user-hovercard\"\u003e\n        \u003cdiv class=\"whatsthis-hovercard\"\u003e\n            \u003ch3\u003eWhat's This?\u003c/h3\u003e\n            \u003cp\u003eThis user has arrived from Restaurant-Kritik.de, a company acquired by Yelp in 2014. We have integrated the two sites to bring you one great local experience.\u003c/p\u003e\n        \u003c/div\u003e\n    \u003c/div\u003e\n");
# yelp.init.attachGhostHovercard("cityvox", "    \u003cdiv id=\"cityvox-ghost-user-hovercard\"\u003e\n        \u003cdiv class=\"whatsthis-hovercard\"\u003e\n            \u003ch3\u003eWhat's This?\u003c/h3\u003e\n            \u003cp\u003eThis user has arrived from Cityvox, a company acquired by Yelp in 2014. We have integrated the two sites to bring you one great local experience.\u003c/p\u003e\n        \u003c/div\u003e\n    \u003c/div\u003e\n");
# yelp.www.init.initAsyncImageLoader();
# yelp.pages.init();
# yelp.common.init.facebook("97534753161", "//connect.facebook.net/en_US/sdk.js", "v8.0", "v8", ["email", "user_birthday", "user_gender"], [], ["user_friends"], true);
# window.YelpReactConsumerHeader.hydrateReactComponent();
# yelp.www.init.user_details.initBadgeHovercards(".user-profile_info");
# yelp.www.init.user_details.initMediaLightbox();
# yelp.www.init.user_details.initReviewActions();
# yelp.www.init.user_details.initMoreGraphsPopup();
# yelp.www.init.user_details.initPhotoSlideshow(".js-photo-slideshow-user-details", [{"photo_id": "qHRuq3b-mgZZzcTnHDFtyg", "source_url": "https://s3-media0.fl.yelpcdn.com/photo/qHRuq3b-mgZZzcTnHDFtyg/ls.jpg", "link_url": "/user_photos?userid=M8eIIxg4zVGeaRFcHNrFCQ", "caption": null, "width": 250, "height": 250, "action_links": null, "alt_text": "Samira S.", "video_properties": null, "load_async": false}, {"photo_id": "UyEp5JwIyWg6I2Kf1THHCw", "source_url": "https://s3-media0.fl.yelpcdn.com/photo/UyEp5JwIyWg6I2Kf1THHCw/ls.jpg", "link_url": "/user_photos?userid=M8eIIxg4zVGeaRFcHNrFCQ", "caption": null, "width": 250, "height": 250, "action_links": null, "alt_text": "Samira S.", "video_properties": null, "load_async": false}]);
# </script>
# <script>
#             (function() {
#                 var main = null;
#
#                 main = function (serviceName, sha) {window.yelp_react = {serviceName: serviceName,sha: sha};};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("yelp_main.www","61ba06c815ef134d66c4ea4d43a5a235a05aed31");
#             })();
#     </script>
# <script>                window.webLogInfo = true;
# </script>
# <script>                window.yClientLogInfo = true;
# </script>
# <script nonce="353ee337">
#             (function() {
#                 var main = null;
#
#                 var main=function(){if(["iPhone","iPod","iPad"].indexOf(navigator.platform)===-1||!window.requestAnimationFrame){return}window.bannerDetectionInitialScroll=window.bannerDetectionInitialScroll||window.scrollY||-100;requestAnimationFrame(function(){window.scrollTo(0,-100);requestAnimationFrame(function(){window.scrollBy(0,1);requestAnimationFrame(function(){window.userHasYelpApp=!window.scrollY;window.scrollTo(0,window.bannerDetectionInitialScroll)})})})};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <script nonce="353ee337">
#             (function() {
#                 var main = null;
#
#                 var main=function loadSpice(i){var l=0;var m=1;var j=2;var g="0";var k="1";var n=function(){if(document.querySelector){return document.querySelector(".delay-spice")}var o=document.getElementsByTagName("div");var r=o.length;var q=new RegExp("(^|\\s)delay-spice(\\s|$)");for(var p=0;p<r;++p){if(q.test(o[p].className)){return o[p]}}return null};function e(){return(window._gaUserPrefs&&window._gaUserPrefs["ioo"]&&typeof(window._gaUserPrefs["ioo"])==="function"&&window._gaUserPrefs["ioo"]()===true||false)?"1":"0"
# }function f(){var o=["__webdriver_evaluate","__selenium_evaluate","__webdriver_script_function","__webdriver_script_func","__webdriver_script_fn","__fxdriver_evaluate","__driver_unwrapped","__webdriver_unwrapped","__driver_evaluate","__selenium_unwrapped","__fxdriver_unwrapped",];var q=["_phantom","__nightmare","_selenium","callPhantom","callSelenium","_Selenium_IDE_Recorder",];var r=0;for(var p=0;p<q.length;p++){if(typeof window[q[p]]!=="undefined"){r+=1}}for(var p=0;p<o.length;p++){if(typeof window.document[o[p]]!=="undefined"){r+=1
# }}return r}function d(){if(typeof window.navigator.permissions!=="undefined"){var o=window.navigator.permissions;return(o.query.toString()!=="function query() { [native code] }"||o.query.toString.toString()!=="function toString() { [native code] }"||o.hasOwnProperty("query"))?1:0}return 2}function h(q,p){var r;if(p===l){r=["/ad_sp","ice?","r=",i]}else{r=["/sp","ice?","r=",i];if(p===j){r.push("&log_ad_spice=1")}}r.push("&pagevis="+q);r.push("&gablock="+e());if(window.webLogInfo&&"navigator" in window){r.push("&webdriver="+(("webdriver" in window.navigator&&window.navigator.webdriver)?1:0))
# }if(window.yClientLogInfo){if("navigator" in window){if(typeof window.navigator.languages!=="undefined"){r.push("&languages="+window.navigator.languages.length)}if(typeof window.navigator.plugins!=="undefined"){r.push("&plugins="+window.navigator.plugins.length)}}r.push("&chrome="+((!!window.chrome)?1:0));r.push("&permissionsSpoofed="+d());r.push("&headlessVarCount="+f())}var o=new Image();o.src=r.join("")}function b(o){if(n()){h(o,m);c(o)}else{h(o,j)}}function c(o){if(n()){window.setTimeout(function(){c(o)
# },500)}else{h(o,l)}}if(!document.webkitHidden){b(g)}else{var a=false;document.addEventListener("webkitvisibilitychange",function(){if(document.webkitHidden||a){return}a=true;b(k)})}};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main("353ee337de5bbe8f");
#             })();
#     </script>
# <script>            yConfig.csrf = {"FacebookTokenRefresh": "15890cacbbe5cd7765c7462c84ac8fcb305f1a51c6ea1891b4b4d8caaa54e22b"};
# </script>
# <div id="ttdUniversalPixelTag290e816a69e9439f960a9588bc2ffb54" style="display:none">
# <script src="https://js.adsrvr.org/up_loader.1.1.0.js" type="text/javascript"></script>
# <script nonce="353ee337">
#             (function() {
#                 var main = null;
#
#                 var main=function(){(function(b){if(typeof TTDUniversalPixelApi==="function"){var a=new TTDUniversalPixelApi();a.init("igcouad",["mvh4ai1"],"https://insight.adsrvr.org/track/up","ttdUniversalPixelTag290e816a69e9439f960a9588bc2ffb54")}})(this)};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# </div>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=102029836881428&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script nonce="353ee337">
#             (function() {
#                 var main = null;
#
#                 var main=function(){var c=Math.random()+"";var b=c*10000000000000;document.write('<iframe src="https://6372968.fls.doubleclick.net/activityi;src=6372968;type=invmedia;cat=qr3hlsqk;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord='+b+'?" width="1" height="1" frameborder="0" style="display:none"></iframe>')};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <noscript>
# <iframe frameborder="0" height="1" src="https://6372968.fls.doubleclick.net/activityi;src=6372968;type=invmedia;cat=qr3hlsqk;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord=1?" style="display:none" width="1"></iframe>
# </noscript>
# <script nonce="353ee337">
#             (function() {
#                 var main = null;
#
#                 var main=function(){var a=new Image(1,1);a.onerror=a.onload=function(){a.onerror=a.onload=null};a.src=["//secure-us.imrworldwide.com/cgi-bin/m?ci=us-804377h&cg=0&cc=1&si=",escape(window.location.href),"&rp=",escape(document.referrer),"&ts=compact&rnd=",(new Date()).getTime()].join("")};
#
#                 if (main === null) {
#                     throw 'invalid inline script, missing main declaration.';
#                 }
#                 main();
#             })();
#     </script>
# <noscript>
# <img alt="" height="1" src="//secure-us.imrworldwide.com/cgi-bin/m?ci=us-804377h&amp;cg=0&amp;cc=1&amp;ts=noscript" width="1"/>
# </noscript>
# </body>
# </html>

# %% [markdown]
# ### Finding the HTML page of user 1

# %%
html_user = requests.get('https://www.yelp.com/user_details?userid=JY6IepgSDkESrtMl1GCD_Q')
soup_user = BeautifulSoup(html_user.content, 'lxml')

# %% [markdown]
# ### Finding the rating distribution

# %%
soup_ratedist = soup_user.select('.histogram_count')

distribution = []

for ratings in soup_ratedist:
    distribution.append(ratings.get_text())

#convert from string to number
distribution = [float(i) for i in distribution]

distribution
# Out:
# [84.0, 157.0, 78.0, 29.0, 10.0]

# %% [markdown]
# ### Find yelping since

# %%
soup_yelpsince = soup_user.select('.ysection li:nth-child(2) p')

yelpsince = []

for since in soup_yelpsince:
    yelpsince.append(since.get_text())

yelpsince
# Out:
# ['September 2009']
